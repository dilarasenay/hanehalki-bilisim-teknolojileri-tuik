# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\HBTKA_HANE_2023.csv" , sep=";")
df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  KAPSAMICI_KAPSAMDISI  BT_BILG_MASAUSTU  \
# 0          2023      10011                     1                 2
# 1          2023      10012                     1                 2
# 2          2023      10013                     1                 2
# 3          2023      10014                     1                 2
# 4          2023      10015                     1                 2
#
#    BT_BILG_DIZUSTU  BT_TABLET  BT_TEL_CEP  BT_DIGER_CIHAZ  \
# 0                1          2           1               2
# 1                1          1           1               1
# 2                2          2           1               2
# 3                2          2           1               1
# 4                2          2           1               2
#
#    HANE_INTERNET_ERISIM_DURUMU  hane_aylik_gelir_grp_5  HHB IBBS_1  \
# 0                            1                       2    1    TR1
# 1                            1                       2    1    TR1
# 2                            1                       1    1    TR1
# 3                            1                       5    6    TR1
# 4                            1                       1    1    TR1
#
#    HANE_FAKTOR
# 0  4107.325497
# 1  4852.032646
# 2  4034.256095
# 3  7267.153007
# 4  4107.325497

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11289 entries, 0 to 11288
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REFERANS_YIL                 11289 non-null  int64
#  1   BULTEN_NO                    11289 non-null  int64
#  2   KAPSAMICI_KAPSAMDISI         11289 non-null  int64
#  3   BT_BILG_MASAUSTU             11289 non-null  int64
#  4   BT_BILG_DIZUSTU              11289 non-null  int64
#  5   BT_TABLET                    11289 non-null  int64
#  6   BT_TEL_CEP                   11289 non-null  int64
#  7   BT_DIGER_CIHAZ               11289 non-null  int64
#  8   HANE_INTERNET_ERISIM_DURUMU  11289 non-null  int64
#  9   hane_aylik_gelir_grp_5       11289 non-null  int64
#  10  HHB                          11289 non-null  int64
#  11  IBBS_1                       11289 non-null  str
#  12  HANE_FAKTOR                  11289 non-null  float64
# dtypes: float64(1), int64(11), str(1)
# memory usage: 1.1 MB

# %%
df.rename(columns={"REFERANS_YIL": "referans yıl"}, inplace=True)
df.rename(columns={"BULTEN_NO": "bülten no"}, inplace=True)
df.rename(columns={"BT_BILG_MASAUSTU": "hanede masaüstü bilgisayar var mı"}, inplace=True)
df.rename(columns={"BT_BILG_DIZUSTU": "hanede dizüstü bilgisayar var mı"}, inplace=True)
df.rename(columns={"BT_TABLET": "hanede tablet var mı"}, inplace=True)
df.rename(columns={"HANE_INTERNET_ERISIM_DURUMU": "hane internet erişim durumu"}, inplace=True)
df.rename(columns={"hane_aylik_gelir_grp_5": "hanenin aylık toplam net geliri (5'li gelir grubu)"}, inplace=True)
df.rename(columns={"HHB": "hane büyüklüğü"}, inplace=True)
df.rename(columns={"IBBS_1": "istatistiki bölge birimleri sınıflaması (düzey 1)"}, inplace=True)
df.rename(columns={"MAH_DEG_L1": "hanehalkı adresinin kır veya kent olma durumu"}, inplace=True)
df.rename(columns={"HANE_FAKTOR": "hane ağırlık katsayısı"}, inplace=True)
df.rename(columns={"BT_TEL_CEP": "hanede cep telefonu var mı"}, inplace=True)
df.rename(columns={"BT_DIGER_CIHAZ": "hanede diğer cihazlar var mı"}, inplace=True)
df.rename(columns={"KAPSAMICI_KAPSAMDISI": "kapsam içi/dışı"}, inplace=True)

# %%
df.head()
# Out:
#    referans yıl  bülten no  kapsam içi/dışı  \
# 0          2023      10011                1
# 1          2023      10012                1
# 2          2023      10013                1
# 3          2023      10014                1
# 4          2023      10015                1
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     1                           1
# 2                     2                           1
# 3                     2                           1
# 4                     2                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             2                            1
# 3                             1                            1
# 4                             2                            1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                   2               1
# 1                                                   2               1
# 2                                                   1               1
# 3                                                   5               6
# 4                                                   1               1
#
#   istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                               TR1             4107.325497
# 1                                               TR1             4852.032646
# 2                                               TR1             4034.256095
# 3                                               TR1             7267.153007
# 4                                               TR1             4107.325497

# %%
df.to_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\hane bilişim temiz veriler\2023temizhanebilişim.csv", index=False)
aa = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\hane bilişim temiz veriler\2023temizhanebilişim.csv")
aa.head()
# Out:
#    referans yıl  bülten no  kapsam içi/dışı  \
# 0          2023      10011                1
# 1          2023      10012                1
# 2          2023      10013                1
# 3          2023      10014                1
# 4          2023      10015                1
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     1                           1
# 2                     2                           1
# 3                     2                           1
# 4                     2                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             2                            1
# 3                             1                            1
# 4                             2                            1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                   2               1
# 1                                                   2               1
# 2                                                   1               1
# 3                                                   5               6
# 4                                                   1               1
#
#   istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                               TR1             4107.325497
# 1                                               TR1             4852.032646
# 2                                               TR1             4034.256095
# 3                                               TR1             7267.153007
# 4                                               TR1             4107.325497

# %% [markdown]
# # 2023 yılı cross tabloları

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
df.head()
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_10956\2291217157.py:2: DtypeWarning: Columns (0: doğduğu ülke kodu, 1: uyruk ülke kodu) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
#    referans yıl  bülten no  fert no  fert cevap durumu  cinsiyet  yaş  eğitim  \
# 0          2023      10011        2                  1         1   45       3
# 1          2023      10012        1                  1         2   25     512
# 2          2023      10013        1                  1         1   58       2
# 3          2023      10014        2                  1         1   25       3
# 4          2023      10014        3                  1         2   40       1
#
#    okuma yazma durumu  çalışma durumu  çalışmama nedeni  ...  \
# 0                 NaN               1               NaN  ...
# 1                 NaN               1               NaN  ...
# 2                 NaN               3               5.0  ...
# 3                 NaN               1               NaN  ...
# 4                 2.0               1               NaN  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı hanede cep telefonu var mı  \
# 0                     2                          1
# 1                     1                          1
# 2                     2                          1
# 3                     2                          1
# 4                     2                          1
#
#    hanede diğer cihazlar var mı hane internet erişim durumu  \
# 0                             2                           1
# 1                             1                           1
# 2                             2                           1
# 3                             1                           1
# 4                             1                           1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                  2                1
# 1                                                  2                1
# 2                                                  1                1
# 3                                                  5                6
# 4                                                  5                6
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             4107.325497
# 1                                                TR1             4852.032646
# 2                                                TR1             4034.256095
# 3                                                TR1             7267.153007
# 4                                                TR1             7267.153007
#
# [5 rows x 173 columns]

# %%
# =========================================================
# ONLINE SAĞLIK HİZMETİ KULLANIMI (VAR / YOK)
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# VAR
online_var = df[df["sağlık bilgisi arama"] == 1]["cinsiyet"] \
    .value_counts()

online_var_yuzde = round(
    df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# YOK
online_yok = df[df["sağlık bilgisi arama"] == 2]["cinsiyet"] \
    .value_counts()

online_yok_yuzde = round(
    df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# TABLO
online_tablo = pd.DataFrame({

    "online sağlık hizmeti kullanımı var": [
        online_var.get(2, 0),
        online_var.get(1, 0),
        online_var.sum()
    ],

    "online sağlık hizmeti kullanımı var yüzde": [
        online_var_yuzde.get(2, 0),
        online_var_yuzde.get(1, 0),
        100
    ],

    "online sağlık hizmeti kullanımı yok": [
        online_yok.get(2, 0),
        online_yok.get(1, 0),
        online_yok.sum()
    ],

    "online sağlık hizmeti kullanımı yok yüzde": [
        online_yok_yuzde.get(2, 0),
        online_yok_yuzde.get(1, 0),
        100
    ]

},

index=["kadın", "erkek", "toplam"]

)

display(online_tablo)
# Out:
#         online sağlık hizmeti kullanımı var  \
# kadın                                  6739
# erkek                                  6724
# toplam                                13463
#
#         online sağlık hizmeti kullanımı var yüzde  \
# kadın                                       50.06
# erkek                                       49.94
# toplam                                     100.00
#
#         online sağlık hizmeti kullanımı yok  \
# kadın                                  3228
# erkek                                  4047
# toplam                                 7275
#
#         online sağlık hizmeti kullanımı yok yüzde
# kadın                                       44.37
# erkek                                       55.63
# toplam                                     100.00

# %%
# =========================================================
# ETİCARET İLAÇ ALIŞVERİŞİ (VAR / YOK)
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# VAR
eticaret_var = df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"] \
    .value_counts()

eticaret_var_yuzde = round(
    df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# YOK
eticaret_yok = df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"] \
    .value_counts()

eticaret_yok_yuzde = round(
    df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# TABLO
eticaret_tablo = pd.DataFrame({

    "eticaret ilaç alışverişi var": [
        eticaret_var.get(2, 0),
        eticaret_var.get(1, 0),
        eticaret_var.sum()
    ],

    "eticaret ilaç alışverişi var yüzde": [
        eticaret_var_yuzde.get(2, 0),
        eticaret_var_yuzde.get(1, 0),
        100
    ],

    "eticaret ilaç alışverişi yok": [
        eticaret_yok.get(2, 0),
        eticaret_yok.get(1, 0),
        eticaret_yok.sum()
    ],

    "eticaret ilaç alışverişi yok yüzde": [
        eticaret_yok_yuzde.get(2, 0),
        eticaret_yok_yuzde.get(1, 0),
        100
    ]

},

index=["kadın", "erkek", "toplam"]

)

display(eticaret_tablo)
# Out:
#         eticaret ilaç alışverişi var  eticaret ilaç alışverişi var yüzde  \
# kadın                            615                               55.96
# erkek                            484                               44.04
# toplam                          1099                              100.00
#
#         eticaret ilaç alışverişi yok  eticaret ilaç alışverişi yok yüzde
# kadın                           3828                               49.48
# erkek                           3908                               50.52
# toplam                          7736                              100.00

# %%
# =========================================================
# GELİR GRUBU x SAĞLIK BİLGİSİ ARAMA
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# 20'Lİ GELİR GRUBUNU 5 EŞİT GRUBA ÇEVİR
# =========================================================

df = df.sort_values(
    "hanenin aylık toplam net geliri (20'li gelir grubu)"
).reset_index(drop=True)

df["gelir_grup"] = pd.qcut(
    df.index,
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt = df[df["gelir_grup"] == gelir]

    # SAĞLIK BİLGİSİ ARAMA VAR
    saglik_var = alt[
        alt["sağlık bilgisi arama"] == 1
    ]

    saglik_var_cinsiyet = (
        saglik_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # SAĞLIK BİLGİSİ ARAMA YOK
    saglik_yok = alt[
        alt["sağlık bilgisi arama"] == 2
    ]

    saglik_yok_cinsiyet = (
        saglik_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2022,

        "gelir": gelir,

        # VAR
        "var kadın":
            round(saglik_var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(saglik_var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(saglik_var),

        # YOK
        "yok kadın":
            round(saglik_yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(saglik_yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(saglik_yok)

    })

# =========================================================
# FREKANS SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2022,

    "gelir": "frekans",

    "var kadın":
        df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["sağlık bilgisi arama"] == 1]),

    "yok kadın":
        df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["sağlık bilgisi arama"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_saglik_2023 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_saglik_2023)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 12
#       8 # =========================================================
#       9 # 20'Lİ GELİR GRUBUNU 5 EŞİT GRUBA ÇEVİR
#      10 # =========================================================
#      11
# ---> 12 df = df.sort_values(
#      13     "hanenin aylık toplam net geliri (20'li gelir grubu)"
#      14 ).reset_index(drop=True)
#      15
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\frame.py:8347, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8343             )
#    8344         elif by:
#    8345             # len(by) == 1
#    8346
# -> 8347             k = self._get_label_or_level_values(by[0], axis=axis)
#    8348
#    8349             # need to rewrap column in Series to apply key function
#    8350             if key is not None:
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: "hanenin aylık toplam net geliri (20'li gelir grubu)"

# %%
df["hanenin aylık toplam net geliri (5'li gelir grubu)"].value_counts()
# Out:
# hanenin aylık toplam net geliri (5'li gelir grubu)
# 3    5096
# 5    5069
# 2    4945
# 4    4921
# 1    4740
# Name: count, dtype: int64

# %%
# =========================================================
# GELİR GRUBU x SAĞLIK BİLGİSİ ARAMA
# 2023
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# HAZIR 5'Lİ GELİR GRUBU
# =========================================================

df["gelir_grup"] = df[
    "hanenin aylık toplam net geliri (5'li gelir grubu)"
]

# =========================================================
# TABLO
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt = df[df["gelir_grup"] == gelir]

    # SAĞLIK BİLGİSİ ARAMA VAR
    saglik_var = alt[
        alt["sağlık bilgisi arama"] == 1
    ]

    saglik_var_cinsiyet = (
        saglik_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # SAĞLIK BİLGİSİ ARAMA YOK
    saglik_yok = alt[
        alt["sağlık bilgisi arama"] == 2
    ]

    saglik_yok_cinsiyet = (
        saglik_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2023,

        "gelir": gelir,

        # VAR
        "var kadın":
            round(saglik_var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(saglik_var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(saglik_var),

        # YOK
        "yok kadın":
            round(saglik_yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(saglik_yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(saglik_yok)

    })

# =========================================================
# FREKANS SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2023,

    "gelir": "frekans",

    "var kadın":
        df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["sağlık bilgisi arama"] == 1]),

    "yok kadın":
        df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["sağlık bilgisi arama"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_saglik_2023 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_saglik_2023)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_17572\1549255150.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir_grup"] = df[
#     yıl    gelir  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2023        1      52.49      47.51        1446      49.97      50.03
# 1  2023        2      51.01      48.99        2376      44.03      55.97
# 2  2023        3      49.03      50.97        2835      43.80      56.20
# 3  2023        4      50.59      49.41        3113      41.85      58.15
# 4  2023        5      48.82      51.18        3693      40.65      59.35
# 5  2023  frekans    6739.00    6724.00       13463    3228.00    4047.00
#
#    yok toplam
# 0        1593
# 1        1724
# 2        1532
# 3        1319
# 4        1107
# 5        7275

# %%
df.head()
# Out:
#    referans yıl  bülten no  fert no  fert cevap durumu  cinsiyet  yaş  eğitim  \
# 0          2023      10011        2                  1         1   45       3
# 1          2023      10012        1                  1         2   25     512
# 2          2023      10013        1                  1         1   58       2
# 3          2023      10014        2                  1         1   25       3
# 4          2023      10014        3                  1         2   40       1
#
#    okuma yazma durumu  çalışma durumu  çalışmama nedeni  ...  \
# 0                 NaN               1               NaN  ...
# 1                 NaN               1               NaN  ...
# 2                 NaN               3               5.0  ...
# 3                 NaN               1               NaN  ...
# 4                 2.0               1               NaN  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı hanede cep telefonu var mı  \
# 0                     2                          1
# 1                     1                          1
# 2                     2                          1
# 3                     2                          1
# 4                     2                          1
#
#    hanede diğer cihazlar var mı hane internet erişim durumu  \
# 0                             2                           1
# 1                             1                           1
# 2                             2                           1
# 3                             1                           1
# 4                             1                           1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                  2                1
# 1                                                  2                1
# 2                                                  1                1
# 3                                                  5                6
# 4                                                  5                6
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             4107.325497
# 1                                                TR1             4852.032646
# 2                                                TR1             4034.256095
# 3                                                TR1             7267.153007
# 4                                                TR1             7267.153007
#
# [5 rows x 173 columns]

# %%
# =========================================================
# GELİR GRUBU x ETİCARET İLAÇ ALIŞVERİŞİ
# HAZIR 5'Lİ GELİR GRUBU KULLAN
# =========================================================

import pandas as pd

# =========================================================
# 5'Lİ GELİR GRUBUNU KULLAN
# =========================================================

df["gelir_grup"] = df[
    "hanenin aylık toplam net geliri (5'li gelir grubu)"
]

# =========================================================
# TABLO
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt = df[df["gelir_grup"] == gelir]

    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    eticaret_var = alt[
        alt["eticaret ilaç alışverişi"] == 1
    ]

    eticaret_var_cinsiyet = (
        eticaret_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    eticaret_yok = alt[
        alt["eticaret ilaç alışverişi"] == 2
    ]

    eticaret_yok_cinsiyet = (
        eticaret_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2023,

        "gelir": gelir,

        # VAR
        "var kadın":
            round(eticaret_var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(eticaret_var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(eticaret_var),

        # YOK
        "yok kadın":
            round(eticaret_yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(eticaret_yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(eticaret_yok)

    })

# =========================================================
# FREKANS SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2023,

    "gelir": "frekans",

    "var kadın":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["eticaret ilaç alışverişi"] == 1]),

    "yok kadın":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["eticaret ilaç alışverişi"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_eticaret_2023 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_eticaret_2023)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_28568\4051434244.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir_grup"] = df[
#     yıl    gelir  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2023        1      56.36      43.64          55      56.44      43.56
# 1  2023        2      58.04      41.96         112      52.15      47.85
# 2  2023        3      57.30      42.70         178      50.73      49.27
# 3  2023        4      59.32      40.68         263      48.45      51.55
# 4  2023        5      53.16      46.84         491      46.39      53.61
# 5  2023  frekans     615.00     484.00        1099    3828.00    3908.00
#
#    yok toplam
# 0         629
# 1        1185
# 2        1573
# 3        1909
# 4        2440
# 5        7736

# %%
# =========================================================
# YAŞ GRUBU x SAĞLIK BİLGİSİ ARAMA
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

df["yas_grup"] = pd.cut(
    df["yaş"],
    bins=[15, 30, 45, 60, 100],
    labels=["15-30", "31-45", "46-60", "60+"],
    include_lowest=True
)

sonuc = []

for yas in ["15-30", "31-45", "46-60", "60+"]:

    alt = df[df["yas_grup"] == yas]

    # SAĞLIK BİLGİSİ ARAMA VAR
    saglik_var = alt[alt["sağlık bilgisi arama"] == 1]

    saglik_var_cinsiyet = (
        saglik_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # SAĞLIK BİLGİSİ ARAMA YOK
    saglik_yok = alt[alt["sağlık bilgisi arama"] == 2]

    saglik_yok_cinsiyet = (
        saglik_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({
        "yıl": 2017,
        "yaş": yas,

        "var kadın": round(saglik_var_cinsiyet.get(2, 0), 2),
        "var erkek": round(saglik_var_cinsiyet.get(1, 0), 2),
        "var toplam": len(saglik_var),

        "yok kadın": round(saglik_yok_cinsiyet.get(2, 0), 2),
        "yok erkek": round(saglik_yok_cinsiyet.get(1, 0), 2),
        "yok toplam": len(saglik_yok)
    })

# =========================================================
# TOPLAM SATIRI - FREKANS
# =========================================================

toplam_satiri = pd.DataFrame([{
    "yıl": 2017,
    "yaş": "toplam",

    "var kadın": df[df["sağlık bilgisi arama"] == 1]["cinsiyet"].value_counts().get(2, 0),
    "var erkek": df[df["sağlık bilgisi arama"] == 1]["cinsiyet"].value_counts().get(1, 0),
    "var toplam": len(df[df["sağlık bilgisi arama"] == 1]),

    "yok kadın": df[df["sağlık bilgisi arama"] == 2]["cinsiyet"].value_counts().get(2, 0),
    "yok erkek": df[df["sağlık bilgisi arama"] == 2]["cinsiyet"].value_counts().get(1, 0),
    "yok toplam": len(df[df["sağlık bilgisi arama"] == 2])
}])

yas_saglik_2017 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(yas_saglik_2017)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_10956\1184860868.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grup"] = pd.cut(
#     yıl     yaş  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2017   15-30      54.05      45.95        4651      42.12      57.88
# 1  2017   31-45      49.80      50.20        5197      44.42      55.58
# 2  2017   46-60      46.34      53.66        2872      46.80      53.20
# 3  2017     60+      41.18      58.82         743      43.30      56.70
# 4  2017  toplam    6739.00    6724.00       13463    3228.00    4047.00
#
#    yok toplam
# 0        1935
# 1        1999
# 2        2237
# 3        1104
# 4        7275

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
df.head()
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_31668\2291217157.py:2: DtypeWarning: Columns (0: doğduğu ülke kodu, 1: uyruk ülke kodu) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
#    referans yıl  bülten no  fert no  fert cevap durumu  cinsiyet  yaş  eğitim  \
# 0          2023      10011        2                  1         1   45       3
# 1          2023      10012        1                  1         2   25     512
# 2          2023      10013        1                  1         1   58       2
# 3          2023      10014        2                  1         1   25       3
# 4          2023      10014        3                  1         2   40       1
#
#    okuma yazma durumu  çalışma durumu  çalışmama nedeni  ...  \
# 0                 NaN               1               NaN  ...
# 1                 NaN               1               NaN  ...
# 2                 NaN               3               5.0  ...
# 3                 NaN               1               NaN  ...
# 4                 2.0               1               NaN  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı hanede cep telefonu var mı  \
# 0                     2                          1
# 1                     1                          1
# 2                     2                          1
# 3                     2                          1
# 4                     2                          1
#
#    hanede diğer cihazlar var mı hane internet erişim durumu  \
# 0                             2                           1
# 1                             1                           1
# 2                             2                           1
# 3                             1                           1
# 4                             1                           1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                  2                1
# 1                                                  2                1
# 2                                                  1                1
# 3                                                  5                6
# 4                                                  5                6
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             4107.325497
# 1                                                TR1             4852.032646
# 2                                                TR1             4034.256095
# 3                                                TR1             7267.153007
# 4                                                TR1             7267.153007
#
# [5 rows x 173 columns]

# %%
# =========================================================
# EĞİTİM x ETİCARET İLAÇ ALIŞVERİŞİ
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# EĞİTİM GRUBU OLUŞTUR
# =========================================================

def egitim_kategori(x):
    if x in [0, 1, 2]:
        return "ilkokulvealtı"
    elif x in [3, 4]:
        return "ortaokul/lise"
    elif x in [5, 51, 52]:
        return "üniversite"
    elif x in [6, 7, 53]:
        return "üniversiteüstü"
    else:
        return None

df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for egitim in ["ilkokulvealtı", "ortaokul/lise", "üniversite", "üniversiteüstü"]:

    alt = df[df["egitim_grup"] == egitim]

    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    eticaret_var = alt[
        alt["eticaret ilaç alışverişi"] == 1
    ]

    eticaret_var_cinsiyet = (
        eticaret_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    eticaret_yok = alt[
        alt["eticaret ilaç alışverişi"] == 2
    ]

    eticaret_yok_cinsiyet = (
        eticaret_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({
        "eğitim": egitim,

        "var kadın": round(eticaret_var_cinsiyet.get(2, 0), 2),
        "var erkek": round(eticaret_var_cinsiyet.get(1, 0), 2),
        "var toplam": len(eticaret_var),

        "yok kadın": round(eticaret_yok_cinsiyet.get(2, 0), 2),
        "yok erkek": round(eticaret_yok_cinsiyet.get(1, 0), 2),
        "yok toplam": len(eticaret_yok)
    })

# =========================================================
# TOPLAM SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{
    "eğitim": "toplam",

    "var kadın": df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"].value_counts().get(2, 0),
    "var erkek": df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"].value_counts().get(1, 0),
    "var toplam": len(df[df["eticaret ilaç alışverişi"] == 1]),

    "yok kadın": df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"].value_counts().get(2, 0),
    "yok erkek": df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"].value_counts().get(1, 0),
    "yok toplam": len(df[df["eticaret ilaç alışverişi"] == 2])
}])

# =========================================================
# BİRLEŞTİR
# =========================================================

egitim_eticaret = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(egitim_eticaret)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_13224\2103775799.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)
#            eğitim  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0   ilkokulvealtı      58.82      41.18          68      54.52      45.48
# 1   ortaokul/lise      51.49      48.51         369      48.14      51.86
# 2      üniversite      50.75      49.25          67      42.81      57.19
# 3  üniversiteüstü      38.89      61.11          18      44.44      55.56
# 4          toplam     615.00     484.00        1099    3828.00    3908.00
#
#    yok toplam
# 0         664
# 1        3932
# 2         278
# 3          63
# 4        7736

# %%
# =========================================================
# YAŞ x ETİCARET İLAÇ ALIŞVERİŞİ
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# YAŞ GRUPLARI
# =========================================================

df["yas_grup"] = pd.cut(
    df["yaş"],
    bins=[15, 30, 45, 60, 100],
    labels=["15-30", "31-45", "46-60", "60+"],
    include_lowest=True
)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for yas in ["15-30", "31-45", "46-60", "60+"]:

    alt = df[df["yas_grup"] == yas]

    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    var_df = alt[
        alt["eticaret ilaç alışverişi"] == 1
    ]

    var_cinsiyet = (
        var_df["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    yok_df = alt[
        alt["eticaret ilaç alışverişi"] == 2
    ]

    yok_cinsiyet = (
        yok_df["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2024,

        "yaş": yas,

        # VAR
        "var kadın":
            round(var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(var_df),

        # YOK
        "yok kadın":
            round(yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(yok_df)

    })

# =========================================================
# TOPLAM SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2024,

    "yaş": "toplam",

    "var kadın":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["eticaret ilaç alışverişi"] == 1]),

    "yok kadın":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["eticaret ilaç alışverişi"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

yas_eticaret = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(yas_eticaret)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_10700\2876047059.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grup"] = pd.cut(
#     yıl     yaş  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2024   15-30      65.06      34.94         395      54.06      45.94
# 1  2024   31-45      55.21      44.79         489      47.71      52.29
# 2  2024   46-60      44.51      55.49         182      41.27      58.73
# 3  2024     60+      21.21      78.79          33      28.89      71.11
# 4  2024  toplam     615.00     484.00        1099    3828.00    3908.00
#
#    yok toplam
# 0        3570
# 1        3035
# 2         996
# 3         135
# 4        7736

# %%
import pandas as pd
import numpy as np

# =========================================================
# EĞİTİM KATEGORİLERİ (2017)
# =========================================================

def egitim_kategori(x):

    if pd.isna(x):
        return None

    x = int(x)

    # İLKOKUL VE ALTI
    if x in [1, 2]:
        return "ilkokulvealtı"

    # ORTAOKUL / LİSE
    elif x in [3, 4]:
        return "ortaokul/lise"

    # ÜNİVERSİTE
    elif x in [51, 52]:
        return "üniversite"

    # ÜNİVERSİTE ÜSTÜ
    elif x in [53]:
        return "üniversiteüstü"

    else:
        return None


# =========================================================
# EĞİTİM GRUBU OLUŞTUR
# =========================================================

df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)

# =========================================================
# SONUÇ LİSTESİ
# =========================================================

sonuc = []

for grup in [
    "ilkokulvealtı",
    "ortaokul/lise",
    "üniversite",
    "üniversiteüstü"
]:

    temp = df[df["egitim_grup"] == grup]

    # =====================================================
    # SAĞLIK BİLGİSİ ARAMA = VAR
    # =====================================================

    var_df = temp[temp["sağlık bilgisi arama"] == 1]

    var_kadin = round(
        (var_df["cinsiyet"].value_counts(normalize=True).get(2, 0)) * 100,
        2
    )

    var_erkek = round(
        (var_df["cinsiyet"].value_counts(normalize=True).get(1, 0)) * 100,
        2
    )

    var_toplam = len(var_df)

    # =====================================================
    # SAĞLIK BİLGİSİ ARAMA = YOK
    # =====================================================

    yok_df = temp[temp["sağlık bilgisi arama"] == 2]

    yok_kadin = round(
        (yok_df["cinsiyet"].value_counts(normalize=True).get(2, 0)) * 100,
        2
    )

    yok_erkek = round(
        (yok_df["cinsiyet"].value_counts(normalize=True).get(1, 0)) * 100,
        2
    )

    yok_toplam = len(yok_df)

    sonuc.append({
        "yıl": 2017,
        "eğitim": grup,
        "var kadın": var_kadin,
        "var erkek": var_erkek,
        "var toplam": var_toplam,
        "yok kadın": yok_kadin,
        "yok erkek": yok_erkek,
        "yok toplam": yok_toplam
    })

# =========================================================
# TOPLAM SATIRI
# =========================================================

var_all = df[df["sağlık bilgisi arama"] == 1]
yok_all = df[df["sağlık bilgisi arama"] == 2]

toplam_satiri = pd.DataFrame([{
    "yıl": 2017,
    "eğitim": "toplam",

    "var kadın": len(var_all[var_all["cinsiyet"] == 2]),
    "var erkek": len(var_all[var_all["cinsiyet"] == 1]),
    "var toplam": len(var_all),

    "yok kadın": len(yok_all[yok_all["cinsiyet"] == 2]),
    "yok erkek": len(yok_all[yok_all["cinsiyet"] == 1]),
    "yok toplam": len(yok_all)
}])

# =========================================================
# BİRLEŞTİR
# =========================================================

egitim_saglik_2017 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(egitim_saglik_2017)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_31668\2140524588.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)
#     yıl          eğitim  var kadın  var erkek  var toplam  yok kadın  \
# 0  2017   ilkokulvealtı      56.52      43.48        2622      55.38
# 1  2017   ortaokul/lise      47.49      52.51        6383      35.02
# 2  2017      üniversite      43.46      56.54         382      32.43
# 3  2017  üniversiteüstü      38.82      61.18          85      42.86
# 4  2017          toplam    6739.00    6724.00       13463    3228.00
#
#    yok erkek  yok toplam
# 0      44.62        3438
# 1      64.98        3081
# 2      67.57          37
# 3      57.14          14
# 4    4047.00        7275

# %%
import pandas as pd
import numpy as np

# =========================================================
# EĞİTİM KATEGORİSİ
# =========================================================
def egitim_kategori(x):

    try:
        x = int(x)
    except:
        return np.nan

    # ilkokul ve altı
    if x in [0, 1]:
        return "ilkokulvealtı"

    # ortaokul / lise
    elif x in [2, 3, 4]:
        return "ortaokul/lise"

    # üniversite
    elif x in [51, 52]:
        return "üniversite"

    # üniversite üstü
    elif x == 53:
        return "üniversiteüstü"

    else:
        return np.nan


# =========================================================
# EĞİTİM GRUBU OLUŞTUR
# =========================================================
df["eğitim_grup"] = df["eğitim"].apply(egitim_kategori)


# =========================================================
# ETİCARET İLAÇ ALIŞVERİŞİ DEĞİŞKENİ
# =========================================================
df["ilac_alisveris"] = df["eticaret ilaç alışverişi"].replace({
    "Evet": 1,
    "Hayır": 0,
    1: 1,
    2: 0
})


# =========================================================
# SONUÇ TABLOSU
# =========================================================
sonuc = []

egitim_sirasi = [
    "ilkokulvealtı",
    "ortaokul/lise",
    "üniversite",
    "üniversiteüstü"
]

for egitim in egitim_sirasi:

    alt = df[df["eğitim_grup"] == egitim]

    # VAR
    var_df = alt[alt["ilac_alisveris"] == 1]

    var_kadin = (var_df["cinsiyet"] == 2).sum()
    var_erkek = (var_df["cinsiyet"] == 1).sum()
    var_toplam = len(var_df)

    # YOK
    yok_df = alt[alt["ilac_alisveris"] == 0]

    yok_kadin = (yok_df["cinsiyet"] == 2).sum()
    yok_erkek = (yok_df["cinsiyet"] == 1).sum()
    yok_toplam = len(yok_df)

    sonuc.append({
        "yıllar": 2015,
        "eğitim": egitim,

        "kadın_var": var_kadin,
        "erkek_var": var_erkek,
        "toplam_var": var_toplam,

        "kadın_yok": yok_kadin,
        "erkek_yok": yok_erkek,
        "toplam_yok": yok_toplam
    })


# =========================================================
# DATAFRAME
# =========================================================
tablo = pd.DataFrame(sonuc)


# =========================================================
# TOPLAM SATIRI
# =========================================================
toplam_satiri = pd.DataFrame([{
    "yıllar": "",
    "eğitim": "toplam",

    "kadın_var": tablo["kadın_var"].sum(),
    "erkek_var": tablo["erkek_var"].sum(),
    "toplam_var": tablo["toplam_var"].sum(),

    "kadın_yok": tablo["kadın_yok"].sum(),
    "erkek_yok": tablo["erkek_yok"].sum(),
    "toplam_yok": tablo["toplam_yok"].sum()
}])


# =========================================================
# FİNAL TABLO
# =========================================================
final_tablo = pd.concat(
    [tablo, toplam_satiri],
    ignore_index=True
)

display(final_tablo)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_31668\2992515238.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["eğitim_grup"] = df["eğitim"].apply(egitim_kategori)
# C:\Users\dilara\AppData\Local\Temp\ipykernel_31668\2992515238.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ilac_alisveris"] = df["eticaret ilaç alışverişi"].replace({
#   yıllar          eğitim  kadın_var  erkek_var  toplam_var  kadın_yok  \
# 0   2015   ilkokulvealtı          0          0           0         32
# 1   2015   ortaokul/lise        230        207         437       2223
# 2   2015      üniversite         34         33          67        119
# 3   2015  üniversiteüstü          7         11          18         28
# 4                 toplam        271        251         522       2402
#
#    erkek_yok  toplam_yok
# 0          8          40
# 1       2333        4556
# 2        159         278
# 3         35          63
# 4       2535        4937

# %%
df[
    (df["eğitim_grup"] == "ilkokulvealtı") &
    (df["ilac_alisveris"] == 1)
]
# Out:
# Empty DataFrame
# Columns: [referans yıl, bülten no, fert no, fert cevap durumu, cinsiyet, yaş, eğitim, okuma yazma durumu, çalışma durumu, çalışmama nedeni, işteki durumu, uluslararası meslek, doğduğu ülke, doğduğu ülke kodu, uyruk, uyruk ülke kodu, cep telefonu kullanımı, cep telefonuna sahip, en son internet ne zaman kullanıldı, internet kullanım sıklığı, masaüstü kullanımı, dizüstü kullanımı, tablet kullanımı, cep telefonu kullanımı.1, diğer cihaz kullanımı, eposta kullanımı, internet araması, sosyal medya kullanımı, sosyal medyada mesajlaşma, online haber okuma, sağlık bilgisi arama, ürün hizmet arama, websitesinde içerik paylaşma, internetten oy katılım, internetten iş arama, Unnamed: 35, internetten satış, online kurs, online eğitim materyal, online eğitim iletişim, whatsapp kullanımı, instagram kullanımı, youtube kullanımı, facebook kullanımı, twitter kullanımı, telegram kullanımı, tiktok kullanımı, snapchat kullanımı, bip kullanımı, diğer mobil uygulama kullanımları, evden çalışma sıklığı, evden çalışırken internet kullanımı , edevlet resmi işlem, edevlet kamu bilgi, edevlet hakkında bilgi, edevlette hiçbir sey yapmadı, edevlet form işlemleri, edevletten randevu alma, edevletten bilgi alma, edevlette vergi beyani verme yönetimi, edevlet belge talep, edevlet yardım talep, edevlet diğer talepler, edevletten talepe ihtiyaç yok, edevlet kullanımı bilgi eksiği, edevlet güven sorunu, edevlet dijital kimlik yok, edevlet işlemlerini başkası yapıyor, edevlet kullanım diğer, edevlet kullanımı zor, edevlet kullanırken teknik sorunlar, edevlet mobil erişim sorunu, edevlette diğer sorunlar, edevlette sorun yok, ekimliği özel amaç için kullanma, ekimliği kamu hizmeti için kullanma, ekimliği özel hizmet için kullanma, ekimlikten haberi yok, ekimlik yok, ekimlik var ama ihtiyaç olmadı, ekimlik var ama kullanımı güvenli değil, ekimliği teknik sorundan kullanamama, ekimlik mobil erişim yok, ekimlik var ama baska sebeplerle kullanmıyorum, eticaret kullanımı, eticaret giyim alışverişi, eticaret spor malzemesi alışverişi, eticaret çocuk oyuncakları ve bakım alışverişi, eticaret ev eşyası alışverişi, eticaret cd plak alışverişi, eticaret dvd plak alışverişi, eticaret kitap dergi alışverişi, eticaret elektronik cihazlar ve aksesuarı alışverişi, eticaret elektronik araçlar alışverişi, eticaret ilaç alışverişi, eticaret yemek siparişi, eticaret gıda ürünleri alışverişi, eticaret kozmetik alışverişi, eticaret temizlik ve kişisel bakım ürünleri alışverişi, eticaret motorlu araç yedekleri alışverişi, ...]
# Index: []
#
# [0 rows x 176 columns]

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
df.head()
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29068\2291217157.py:2: DtypeWarning: Columns (0: doğduğu ülke kodu, 1: uyruk ülke kodu) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
#    referans yıl  bülten no  fert no  fert cevap durumu  cinsiyet  yaş  eğitim  \
# 0          2023      10011        2                  1         1   45       3
# 1          2023      10012        1                  1         2   25     512
# 2          2023      10013        1                  1         1   58       2
# 3          2023      10014        2                  1         1   25       3
# 4          2023      10014        3                  1         2   40       1
#
#    okuma yazma durumu  çalışma durumu  çalışmama nedeni  ...  \
# 0                 NaN               1               NaN  ...
# 1                 NaN               1               NaN  ...
# 2                 NaN               3               5.0  ...
# 3                 NaN               1               NaN  ...
# 4                 2.0               1               NaN  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı hanede cep telefonu var mı  \
# 0                     2                          1
# 1                     1                          1
# 2                     2                          1
# 3                     2                          1
# 4                     2                          1
#
#    hanede diğer cihazlar var mı hane internet erişim durumu  \
# 0                             2                           1
# 1                             1                           1
# 2                             2                           1
# 3                             1                           1
# 4                             1                           1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                  2                1
# 1                                                  2                1
# 2                                                  1                1
# 3                                                  5                6
# 4                                                  5                6
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             4107.325497
# 1                                                TR1             4852.032646
# 2                                                TR1             4034.256095
# 3                                                TR1             7267.153007
# 4                                                TR1             7267.153007
#
# [5 rows x 173 columns]

# %%
# =========================================================
# CİNSİYET FREKANS + YÜZDE + TOPLAM
# =========================================================

import pandas as pd

# Etiket
df["cinsiyet_label"] = df["cinsiyet"].replace({
    1: "Erkek",
    2: "Kadın"
})

# Frekans
frekans = df["cinsiyet_label"].value_counts().sort_index()

# Yüzde
yuzde = round(
    df["cinsiyet_label"].value_counts(normalize=True).sort_index() * 100,
    2
)

# Tablo
final_tablo = pd.DataFrame({
    "toplam": frekans,
    "yüzde": yuzde
}).reset_index()

final_tablo.columns = ["cinsiyet", "toplam", "yüzde"]

# TOPLAM SATIRI
toplam_satiri = pd.DataFrame([{
    "cinsiyet": "Toplam",
    "toplam": final_tablo["toplam"].sum(),
    "yüzde": round(final_tablo["yüzde"].sum(), 2)
}])

# Birleştir
final_tablo = pd.concat(
    [final_tablo, toplam_satiri],
    ignore_index=True
)

display(final_tablo)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29068\3164738277.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cinsiyet_label"] = df["cinsiyet"].replace({
#   cinsiyet  toplam   yüzde
# 0    Erkek   12245   49.43
# 1    Kadın   12526   50.57
# 2   Toplam   24771  100.00

# %%
import pandas as pd
import numpy as np

# =========================================================
# YIL
# =========================================================
YIL = 2025


# =========================================================
# TÜM YILLARA UYUMLU EĞİTİM KATEGORİSİ
# =========================================================
def egitim_kategori(x):

    try:
        x = int(x)
    except:
        return np.nan

    # -------------------------------------------------
    # İLKOKUL VE ALTI
    # -------------------------------------------------
    if x in [0, 1, 2]:
        return "ilkokulvealtı"

    # -------------------------------------------------
    # ORTAOKUL / LİSE
    # -------------------------------------------------
    elif x in [3, 4]:
        return "ortaokul/lise"

    # -------------------------------------------------
    # ÜNİVERSİTE
    # -------------------------------------------------
    elif x in [5, 6, 51, 52, 511, 512]:
        return "üniversite"

    # -------------------------------------------------
    # ÜNİVERSİTE ÜSTÜ
    # -------------------------------------------------
    elif x in [7, 53]:
        return "üniversiteüstü"

    else:
        return np.nan


# =========================================================
# EĞİTİM GRUBU
# =========================================================
df["eğitim_grup"] = df["eğitim"].apply(egitim_kategori)


# =========================================================
# ETİCARET İLAÇ ALIŞVERİŞİ
# =========================================================
df["ilac_alisveris"] = df["eticaret ilaç alışverişi"].replace({
    "Evet": 1,
    "Hayır": 0,
    1: 1,
    2: 0
})


# =========================================================
# SONUÇ TABLOSU
# =========================================================
sonuc = []

egitim_sirasi = [
    "ilkokulvealtı",
    "ortaokul/lise",
    "üniversite",
    "üniversiteüstü"
]

for egitim in egitim_sirasi:

    alt = df[df["eğitim_grup"] == egitim]

    # =====================================================
    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    # =====================================================
    var_df = alt[alt["ilac_alisveris"] == 1]

    var_kadin = (var_df["cinsiyet"] == 2).sum()
    var_erkek = (var_df["cinsiyet"] == 1).sum()
    var_toplam = len(var_df)

    # =====================================================
    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    # =====================================================
    yok_df = alt[alt["ilac_alisveris"] == 0]

    yok_kadin = (yok_df["cinsiyet"] == 2).sum()
    yok_erkek = (yok_df["cinsiyet"] == 1).sum()
    yok_toplam = len(yok_df)

    # =====================================================
    # SATIR EKLE
    # =====================================================
    sonuc.append({

        "yıllar": YIL,
        "eğitim": egitim,

        "kadın_var": var_kadin,
        "erkek_var": var_erkek,
        "toplam_var": var_toplam,

        "kadın_yok": yok_kadin,
        "erkek_yok": yok_erkek,
        "toplam_yok": yok_toplam
    })


# =========================================================
# DATAFRAME
# =========================================================
tablo = pd.DataFrame(sonuc)


# =========================================================
# TOPLAM SATIRI
# =========================================================
toplam_satiri = pd.DataFrame([{

    "yıllar": "",
    "eğitim": "toplam",

    "kadın_var": tablo["kadın_var"].sum(),
    "erkek_var": tablo["erkek_var"].sum(),
    "toplam_var": tablo["toplam_var"].sum(),

    "kadın_yok": tablo["kadın_yok"].sum(),
    "erkek_yok": tablo["erkek_yok"].sum(),
    "toplam_yok": tablo["toplam_yok"].sum()

}])


# =========================================================
# FİNAL TABLO
# =========================================================
final_tablo = pd.concat(
    [tablo, toplam_satiri],
    ignore_index=True
)


# =========================================================
# GÖSTER
# =========================================================
display(final_tablo)


# =========================================================
# EXCEL AKTAR
# =========================================================
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_16636\1077536611.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["eğitim_grup"] = df["eğitim"].apply(egitim_kategori)
# C:\Users\dilara\AppData\Local\Temp\ipykernel_16636\1077536611.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ilac_alisveris"] = df["eticaret ilaç alışverişi"].replace({
#   yıllar          eğitim  kadın_var  erkek_var  toplam_var  kadın_yok  \
# 0   2025   ilkokulvealtı         40         28          68        362
# 1   2025   ortaokul/lise        190        179         369       1893
# 2   2025      üniversite        378        266         644       1545
# 3   2025  üniversiteüstü          7         11          18         28
# 4                 toplam        615        484        1099       3828
#
#    erkek_yok  toplam_yok
# 0        302         664
# 1       2039        3932
# 2       1532        3077
# 3         35          63
# 4       3908        7736

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
df.head()
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_24168\2291217157.py:2: DtypeWarning: Columns (0: doğduğu ülke kodu, 1: uyruk ülke kodu) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
#    referans yıl  bülten no  fert no  fert cevap durumu  cinsiyet  yaş  eğitim  \
# 0          2023      10011        2                  1         1   45       3
# 1          2023      10012        1                  1         2   25     512
# 2          2023      10013        1                  1         1   58       2
# 3          2023      10014        2                  1         1   25       3
# 4          2023      10014        3                  1         2   40       1
#
#    okuma yazma durumu  çalışma durumu  çalışmama nedeni  ...  \
# 0                 NaN               1               NaN  ...
# 1                 NaN               1               NaN  ...
# 2                 NaN               3               5.0  ...
# 3                 NaN               1               NaN  ...
# 4                 2.0               1               NaN  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı hanede cep telefonu var mı  \
# 0                     2                          1
# 1                     1                          1
# 2                     2                          1
# 3                     2                          1
# 4                     2                          1
#
#    hanede diğer cihazlar var mı hane internet erişim durumu  \
# 0                             2                           1
# 1                             1                           1
# 2                             2                           1
# 3                             1                           1
# 4                             1                           1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                  2                1
# 1                                                  2                1
# 2                                                  1                1
# 3                                                  5                6
# 4                                                  5                6
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             4107.325497
# 1                                                TR1             4852.032646
# 2                                                TR1             4034.256095
# 3                                                TR1             7267.153007
# 4                                                TR1             7267.153007
#
# [5 rows x 173 columns]

# %%
import pandas as pd
import numpy as np

# =========================================================
# YAŞ GRUPLARI
# =========================================================

def yas_grup(yas):

    if pd.isna(yas):
        return np.nan

    elif 15 <= yas <= 30:
        return "15-30"

    elif 31 <= yas <= 45:
        return "31-45"

    elif 46 <= yas <= 60:
        return "46-60"

    else:
        return "60+"

# yeni değişken
df["yas_grubu"] = df["yaş"].apply(yas_grup)

# =========================================================
# FREKANS + YÜZDE
# =========================================================

frekans = df["yas_grubu"].value_counts().sort_index()

yuzde = round(
    df["yas_grubu"].value_counts(normalize=True).sort_index() * 100,
    2
)

# =========================================================
# TABLO
# =========================================================

yas_tablo = pd.DataFrame({
    "toplam": frekans,
    "yüzde": yuzde
})

# toplam satırı
toplam_satiri = pd.DataFrame({
    "toplam": [yas_tablo["toplam"].sum()],
    "yüzde": [100]
}, index=["toplam"])

yas_tablo = pd.concat([yas_tablo, toplam_satiri])

display(yas_tablo)

# =========================================================
# EXCEL AKTAR
# =========================================================
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_24168\1794991821.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grubu"] = df["yaş"].apply(yas_grup)
#         toplam   yüzde
# 15-30     6858   27.69
# 31-45     7600   30.68
# 46-60     6295   25.41
# 60+       4018   16.22
# toplam   24771  100.00

# %%
import pandas as pd
import numpy as np

# =========================================================
# EĞİTİM GRUPLAMA
# =========================================================
def egitim_kategori(x):
    try:
        x = int(x)
    except:
        return np.nan

    if x in [0, 1, 2]:
        return "ilkokulvealtı"
    elif x in [3, 4]:
        return "ortaokul/lise"
    elif x in [5, 6, 51, 511, 512]:
        return "üniversite"
    elif x in [7, 52, 53]:
        return "üniversiteüstü"
    else:
        return np.nan

df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)

# =========================================================
# FREKANS + YÜZDE
# =========================================================
egitim_sirasi = [
    "ilkokulvealtı",
    "ortaokul/lise",
    "üniversite",
    "üniversiteüstü"
]

frekans = df["egitim_grup"].value_counts().reindex(egitim_sirasi)
yuzde = round(df["egitim_grup"].value_counts(normalize=True).reindex(egitim_sirasi) * 100, 2)

egitim_tablo = pd.DataFrame({
    "toplam": frekans,
    "yüzde": yuzde
})

# =========================================================
# TOPLAM SATIRI
# =========================================================
toplam_satiri = pd.DataFrame({
    "toplam": [egitim_tablo["toplam"].sum()],
    "yüzde": [100]
}, index=["toplam"])

egitim_tablo = pd.concat([egitim_tablo, toplam_satiri])

display(egitim_tablo)

# =========================================================
# EXCEL AKTAR
# =========================================================
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_24168\3341891636.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)
#                 toplam   yüzde
# ilkokulvealtı     9524   38.45
# ortaokul/lise     9990   40.33
# üniversite        4739   19.13
# üniversiteüstü     518    2.09
# toplam           24771  100.00

# %%
import pandas as pd
import numpy as np

# =========================================================
# GELİR DEĞİŞKENİ
# =========================================================

gelir_col = "hanenin aylık toplam net geliri (5'li gelir grubu)"

# numerik yap
df["gelir_raw"] = pd.to_numeric(
    df[gelir_col],
    errors="coerce"
)

# =========================================================
# ZORLA EŞİT 5 GRUP
# =========================================================

df["gelir_5li_esit"] = pd.qcut(
    df["gelir_raw"].rank(method="first"),
    q=5,
    labels=[
        "1. grup",
        "2. grup",
        "3. grup",
        "4. grup",
        "5. grup"
    ]
)

# =========================================================
# FREKANS + YÜZDE
# =========================================================

gelir_sirasi = [
    "1. grup",
    "2. grup",
    "3. grup",
    "4. grup",
    "5. grup"
]

frekans = (
    df["gelir_5li_esit"]
    .value_counts()
    .reindex(gelir_sirasi)
)

yuzde = round(
    (
        df["gelir_5li_esit"]
        .value_counts(normalize=True)
        .reindex(gelir_sirasi)
    ) * 100,
    2
)

# =========================================================
# TABLO
# =========================================================

gelir_tablo = pd.DataFrame({
    "toplam": frekans,
    "yüzde": yuzde
})

# =========================================================
# TOPLAM SATIRI
# =========================================================

toplam_satiri = pd.DataFrame({
    "toplam": [gelir_tablo["toplam"].sum()],
    "yüzde": [100]
}, index=["toplam"])

gelir_tablo = pd.concat(
    [gelir_tablo, toplam_satiri]
)

display(gelir_tablo)

# =========================================================
# EXCEL AKTAR
# =========================================================
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_24168\835301591.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir_raw"] = pd.to_numeric(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_24168\835301591.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir_5li_esit"] = pd.qcut(
#          toplam  yüzde
# 1. grup    4955   20.0
# 2. grup    4954   20.0
# 3. grup    4954   20.0
# 4. grup    4954   20.0
# 5. grup    4954   20.0
# toplam    24771  100.0

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
df.head()
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\2291217157.py:2: DtypeWarning: Columns (0: doğduğu ülke kodu, 1: uyruk ülke kodu) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2023.csv")
#    referans yıl  bülten no  fert no  fert cevap durumu  cinsiyet  yaş  eğitim  \
# 0          2023      10011        2                  1         1   45       3
# 1          2023      10012        1                  1         2   25     512
# 2          2023      10013        1                  1         1   58       2
# 3          2023      10014        2                  1         1   25       3
# 4          2023      10014        3                  1         2   40       1
#
#    okuma yazma durumu  çalışma durumu  çalışmama nedeni  ...  \
# 0                 NaN               1               NaN  ...
# 1                 NaN               1               NaN  ...
# 2                 NaN               3               5.0  ...
# 3                 NaN               1               NaN  ...
# 4                 2.0               1               NaN  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 1
# 1                                  2                                 1
# 2                                  2                                 2
# 3                                  2                                 2
# 4                                  2                                 2
#
#    hanede tablet var mı hanede cep telefonu var mı  \
# 0                     2                          1
# 1                     1                          1
# 2                     2                          1
# 3                     2                          1
# 4                     2                          1
#
#    hanede diğer cihazlar var mı hane internet erişim durumu  \
# 0                             2                           1
# 1                             1                           1
# 2                             2                           1
# 3                             1                           1
# 4                             1                           1
#
#    hanenin aylık toplam net geliri (5'li gelir grubu)  hane büyüklüğü  \
# 0                                                  2                1
# 1                                                  2                1
# 2                                                  1                1
# 3                                                  5                6
# 4                                                  5                6
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             4107.325497
# 1                                                TR1             4852.032646
# 2                                                TR1             4034.256095
# 3                                                TR1             7267.153007
# 4                                                TR1             7267.153007
#
# [5 rows x 173 columns]

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# =====================================================
# MODEL 1 - PROBIT MODEL
# Bağımlı değişken: Online sağlık hizmeti kullanımı
#
# Gelir değişkeni:
# hanenin aylık toplam net geliri (20'li gelir grubu)
# =====================================================

# 1) ONLINE SAĞLIK
df["online_saglik"] = df["sağlık bilgisi arama"].replace({
    "Evet": 1, "Hayır": 0,
    "evet": 1, "hayır": 0,
    "EVET": 1, "HAYIR": 0,
    1: 1, 2: 0, 0: 0
})

# 2) CİNSİYET
df["cinsiyet_kadin"] = df["cinsiyet"].replace({
    "Erkek": 0, "Kadın": 1,
    "erkek": 0, "kadın": 1,
    "ERKEK": 0, "KADIN": 1,
    1: 0, 2: 1
})

# 3) YAŞ KATEGORİLERİ
df["yas"] = pd.to_numeric(df["yaş"], errors="coerce")

df["yas_grup"] = pd.cut(
    df["yas"],
    bins=[14, 30, 45, 60, 120],
    labels=["15-30", "31-45", "46-60", "60+"]
)

yas_dummy = pd.get_dummies(df["yas_grup"], prefix="yas")
yas_dummy = yas_dummy.drop(columns=["yas_15-30"], errors="ignore")

# 4) EĞİTİM KATEGORİLERİ
df["egitim_sayi"] = pd.to_numeric(df["eğitim"], errors="coerce")

def egitim_kategori(x):
    if x in [1]:
        return "Ilkokul_ve_alti"
    elif x in [2, 3, 4]:
        return "Orta_Lise"
    elif x in [51, 52, 53]:
        return "Universite_ve_ustu"
    else:
        return np.nan

df["egitim_grup"] = df["egitim_sayi"].apply(egitim_kategori)

egitim_dummy = pd.get_dummies(df["egitim_grup"], prefix="egitim")
egitim_dummy = egitim_dummy.drop(
    columns=["egitim_Ilkokul_ve_alti"],
    errors="ignore"
)

# 5) GELİR - 20'Lİ GELİR GRUBU
df["gelir"] = pd.to_numeric(
    df["hanenin aylık toplam net geliri (20'li gelir grubu)"],
    errors="coerce"
)

df["log_gelir"] = np.log1p(df["gelir"])

# 6) MODEL DATAFRAME
model_df = pd.concat(
    [
        df[["online_saglik", "cinsiyet_kadin", "log_gelir"]],
        yas_dummy,
        egitim_dummy
    ],
    axis=1
)

# 7) SAYISALA ÇEVİR VE TEMİZLE
model_df = model_df.apply(pd.to_numeric, errors="coerce")

print("Dropna öncesi satır sayısı:", len(model_df))
print("\nEksik değer sayıları:")
print(model_df.isna().sum())

model_df = model_df.dropna()

print("\nDropna sonrası satır sayısı:", len(model_df))

# 8) X ve y
y = model_df["online_saglik"]
X = model_df.drop(columns=["online_saglik"])

X = sm.add_constant(X)

X = X.astype(float)
y = y.astype(float)

# 9) KONTROLLER
print("\nBağımlı değişken dağılımı:")
print(y.value_counts())

print("\nEğitim grubu dağılımı:")
print(df["egitim_grup"].value_counts(dropna=False))

print("\nGelir değişkeni dağılımı:")
print(df["gelir"].value_counts(dropna=False).sort_index())

print("\nModel değişkenleri:")
print(X.columns)

# 10) PROBIT MODEL
probit_model = sm.Probit(y, X)
result = probit_model.fit()

print(result.summary().as_text())
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3297545325.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["online_saglik"] = df["sağlık bilgisi arama"].replace({
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3297545325.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cinsiyet_kadin"] = df["cinsiyet"].replace({
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3297545325.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas"] = pd.to_numeric(df["yaş"], errors="coerce")
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3297545325.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grup"] = pd.cut(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3297545325.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_sayi"] = pd.to_numeric(df["eğitim"], errors="coerce")
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3297545325.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_grup"] = df["egitim_sayi"].apply(egitim_kategori)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: "hanenin aylık toplam net geliri (20'li gelir grubu)"
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 64
#      60 )
#      61
#      62 # 5) GELİR - 20'Lİ GELİR GRUBU
#      63 df["gelir"] = pd.to_numeric(
# ---> 64     df["hanenin aylık toplam net geliri (20'li gelir grubu)"],
#      65     errors="coerce"
#      66 )
#      67
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: "hanenin aylık toplam net geliri (20'li gelir grubu)"

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# =====================================================
# MODEL 1 - PROBIT MODEL (2022)
# Bağımlı değişken:
# Online sağlık hizmeti kullanımı
#
# Referans Gruplar:
# Cinsiyet -> Erkek
# Yaş -> 15-30
# Eğitim -> İlkokul ve altı
# Gelir -> 5'li gelir grubu
# =====================================================

# -----------------------------------------------------
# 1) ONLINE SAĞLIK HİZMETİ KULLANIMI
# -----------------------------------------------------

df["online_saglik"] = df["sağlık bilgisi arama"].replace({
    "Evet": 1,
    "Hayır": 0,
    "evet": 1,
    "hayır": 0,
    "EVET": 1,
    "HAYIR": 0,
    1: 1,
    2: 0,
    0: 0
})

# -----------------------------------------------------
# 2) CİNSİYET
# Erkek = 0
# Kadın = 1
# -----------------------------------------------------

df["cinsiyet_kadin"] = df["cinsiyet"].replace({
    "Erkek": 0,
    "Kadın": 1,
    "erkek": 0,
    "kadın": 1,
    "ERKEK": 0,
    "KADIN": 1,
    1: 0,
    2: 1
})

# -----------------------------------------------------
# 3) YAŞ KATEGORİLERİ
# -----------------------------------------------------

df["yas"] = pd.to_numeric(
    df["yaş"],
    errors="coerce"
)

df["yas_grup"] = pd.cut(
    df["yas"],
    bins=[14, 30, 45, 60, 120],
    labels=[
        "15-30",
        "31-45",
        "46-60",
        "60+"
    ]
)

yas_dummy = pd.get_dummies(
    df["yas_grup"],
    prefix="yas"
)

# REFERANS YAŞ GRUBU
yas_dummy = yas_dummy.drop(
    columns=["yas_15-30"],
    errors="ignore"
)

# -----------------------------------------------------
# 4) EĞİTİM KATEGORİLERİ (2022)
# -----------------------------------------------------

df["egitim_sayi"] = pd.to_numeric(
    df["eğitim"],
    errors="coerce"
)

def egitim_kategori(x):

    # REFERANS GRUP
    if x in [1]:
        return "Ilkokul_ve_alti"

    # ORTAOKUL / LİSE
    elif x in [2, 3, 4]:
        return "Orta_Lise"

    # ÜNİVERSİTE VE ÜSTÜ
    elif x in [511, 512, 52, 53]:
        return "Universite_ve_ustu"

    else:
        return np.nan

df["egitim_grup"] = df["egitim_sayi"].apply(
    egitim_kategori
)

egitim_dummy = pd.get_dummies(
    df["egitim_grup"],
    prefix="egitim"
)

# REFERANS EĞİTİM GRUBU
egitim_dummy = egitim_dummy.drop(
    columns=["egitim_Ilkokul_ve_alti"],
    errors="ignore"
)

# -----------------------------------------------------
# 5) GELİR (5'Lİ GELİR GRUBU)
# -----------------------------------------------------

df["gelir"] = pd.to_numeric(
    df["hanenin aylık toplam net geliri (5'li gelir grubu)"],
    errors="coerce"
)

# LOG GELİR
df["log_gelir"] = np.log1p(df["gelir"])

# -----------------------------------------------------
# 6) MODEL DATAFRAME
# -----------------------------------------------------

model_df = pd.concat(
    [
        df[
            [
                "online_saglik",
                "cinsiyet_kadin",
                "log_gelir"
            ]
        ],
        yas_dummy,
        egitim_dummy
    ],
    axis=1
)

# -----------------------------------------------------
# 7) TÜM DEĞİŞKENLERİ SAYISALA ÇEVİR
# -----------------------------------------------------

model_df = model_df.apply(
    pd.to_numeric,
    errors="coerce"
)

print("Dropna öncesi satır sayısı:")
print(len(model_df))

print("\nEksik değer sayıları:")
print(model_df.isna().sum())

# Eksik gözlemleri temizle
model_df = model_df.dropna()

print("\nDropna sonrası satır sayısı:")
print(len(model_df))

# -----------------------------------------------------
# 8) X ve y
# -----------------------------------------------------

y = model_df["online_saglik"]

X = model_df.drop(
    columns=["online_saglik"]
)

# CONSTANT
X = sm.add_constant(X)

# FLOAT
X = X.astype(float)
y = y.astype(float)

# -----------------------------------------------------
# 9) KONTROLLER
# -----------------------------------------------------

print("\nBağımlı değişken dağılımı:")
print(y.value_counts())

print("\nEğitim grubu dağılımı:")
print(df["egitim_grup"].value_counts(dropna=False))

print("\nGelir dağılımı:")
print(df["gelir"].value_counts(dropna=False).sort_index())

print("\nModel değişkenleri:")
print(X.columns)

# -----------------------------------------------------
# 10) PROBIT MODEL
# -----------------------------------------------------

probit_model = sm.Probit(y, X)

result = probit_model.fit()

# -----------------------------------------------------
# 11) SONUÇLAR
# -----------------------------------------------------

summary_text = result.summary().as_text()

print(summary_text)

# -----------------------------------------------------
# 12) MARGINAL EFFECTS
# -----------------------------------------------------

marginal = result.get_margeff()

print(marginal.summary())
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3618838754.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir"] = pd.to_numeric(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_820\3618838754.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["log_gelir"] = np.log1p(df["gelir"])
# Dropna öncesi satır sayısı:
# 24771
#
# Eksik değer sayıları:
# online_saglik                4033
# cinsiyet_kadin                  0
# log_gelir                       0
# yas_31-45                       0
# yas_46-60                       0
# yas_60+                         0
# egitim_Orta_Lise                0
# egitim_Universite_ve_ustu       0
# dtype: int64
#
# Dropna sonrası satır sayısı:
# 20738
#
# Bağımlı değişken dağılımı:
# online_saglik
# 1.0    13463
# 0.0     7275
# Name: count, dtype: int64
#
# Eğitim grubu dağılımı:
# egitim_grup
# Orta_Lise             17384
# Universite_ve_ustu     5257
# Ilkokul_ve_alti        2130
# Name: count, dtype: int64
#
# Gelir dağılımı:
# gelir
# 1    4740
# 2    4945
# 3    5096
# 4    4921
# 5    5069
# Name: count, dtype: int64
#
# Model değişkenleri:
# Index(['const', 'cinsiyet_kadin', 'log_gelir', 'yas_31-45', 'yas_46-60',
#        'yas_60+', 'egitim_Orta_Lise', 'egitim_Universite_ve_ustu'],
#       dtype='str')
# Optimization terminated successfully.
#          Current function value: 0.578189
#          Iterations 5
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:          online_saglik   No. Observations:                20738
# Model:                         Probit   Df Residuals:                    20730
# Method:                           MLE   Df Model:                            7
# Date:                Fri, 15 May 2026   Pseudo R-squ.:                  0.1077
# Time:                        09:48:48   Log-Likelihood:                -11990.
# converged:                       True   LL-Null:                       -13437.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -1.2849      0.067    -19.122      0.000      -1.417      -1.153
# cinsiyet_kadin                0.2013      0.019     10.595      0.000       0.164       0.238
# log_gelir                     0.4325      0.026     16.374      0.000       0.381       0.484
# yas_31-45                     0.0436      0.024      1.850      0.064      -0.003       0.090
# yas_46-60                    -0.3246      0.025    -13.108      0.000      -0.373      -0.276
# yas_60+                      -0.6849      0.035    -19.619      0.000      -0.753      -0.617
# egitim_Orta_Lise              1.0155      0.057     17.937      0.000       0.905       1.126
# egitim_Universite_ve_ustu     1.6889      0.061     27.903      0.000       1.570       1.807
# =============================================================================================
#        Probit Marginal Effects
# =====================================
# Dep. Variable:          online_saglik
# Method:                          dydx
# At:                           overall
# =============================================================================================
#                                dy/dx    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# cinsiyet_kadin                0.0661      0.006     10.679      0.000       0.054       0.078
# log_gelir                     0.1420      0.009     16.696      0.000       0.125       0.159
# yas_31-45                     0.0143      0.008      1.850      0.064      -0.001       0.029
# yas_46-60                    -0.1066      0.008    -13.268      0.000      -0.122      -0.091
# yas_60+                      -0.2249      0.011    -20.182      0.000      -0.247      -0.203
# egitim_Orta_Lise              0.3334      0.018     18.358      0.000       0.298       0.369
# egitim_Universite_ve_ustu     0.5545      0.019     29.469      0.000       0.518       0.591
# =============================================================================================

# %%
summary_text = result.summary().as_text()

print(summary_text)
# Out:
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:          online_saglik   No. Observations:                20738
# Model:                         Probit   Df Residuals:                    20730
# Method:                           MLE   Df Model:                            7
# Date:                Fri, 15 May 2026   Pseudo R-squ.:                  0.1077
# Time:                        09:48:56   Log-Likelihood:                -11990.
# converged:                       True   LL-Null:                       -13437.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -1.2849      0.067    -19.122      0.000      -1.417      -1.153
# cinsiyet_kadin                0.2013      0.019     10.595      0.000       0.164       0.238
# log_gelir                     0.4325      0.026     16.374      0.000       0.381       0.484
# yas_31-45                     0.0436      0.024      1.850      0.064      -0.003       0.090
# yas_46-60                    -0.3246      0.025    -13.108      0.000      -0.373      -0.276
# yas_60+                      -0.6849      0.035    -19.619      0.000      -0.753      -0.617
# egitim_Orta_Lise              1.0155      0.057     17.937      0.000       0.905       1.126
# egitim_Universite_ve_ustu     1.6889      0.061     27.903      0.000       1.570       1.807
# =============================================================================================

# %%
df["eğitim"].value_counts()
# Out:
# eğitim
# 2      7394
# 4      5915
# 3      4075
# 512    3214
# 1      2130
# 511    1525
# 52      419
# 53       99
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# =====================================================
# MODEL 1 - PROBIT MODEL
# Bağımlı değişken: Online sağlık hizmeti kullanımı
# Gelir: 5'li gelir grubu
# Eğitim: Orta/Lise, Üniversite, Doktora ayrı
# =====================================================

# 1) ONLINE SAĞLIK
df["online_saglik"] = df["sağlık bilgisi arama"].replace({
    "Evet": 1, "Hayır": 0,
    "evet": 1, "hayır": 0,
    "EVET": 1, "HAYIR": 0,
    1: 1, 2: 0, 0: 0
})

# 2) CİNSİYET
df["cinsiyet_kadin"] = df["cinsiyet"].replace({
    "Erkek": 0, "Kadın": 1,
    "erkek": 0, "kadın": 1,
    "ERKEK": 0, "KADIN": 1,
    1: 0, 2: 1
})

# 3) YAŞ KATEGORİLERİ
df["yas"] = pd.to_numeric(df["yaş"], errors="coerce")

df["yas_grup"] = pd.cut(
    df["yas"],
    bins=[14, 30, 45, 60, 120],
    labels=["15-30", "31-45", "46-60", "60+"]
)

yas_dummy = pd.get_dummies(df["yas_grup"], prefix="yas")
yas_dummy = yas_dummy.drop(columns=["yas_15-30"], errors="ignore")

# 4) EĞİTİM KATEGORİLERİ
df["egitim_sayi"] = pd.to_numeric(df["eğitim"], errors="coerce")

def egitim_kategori(x):
    if x in [1]:
        return "Ilkokul_ve_alti"
    elif x in [2, 3, 4]:
        return "Orta_Lise"
    elif x in [511, 512, 52]:
        return "Universite"
    elif x in [53]:
        return "Doktora"
    else:
        return np.nan

df["egitim_grup"] = df["egitim_sayi"].apply(egitim_kategori)

egitim_dummy = pd.get_dummies(df["egitim_grup"], prefix="egitim")

# Referans eğitim grubu: İlkokul ve altı
egitim_dummy = egitim_dummy.drop(
    columns=["egitim_Ilkokul_ve_alti"],
    errors="ignore"
)

# 5) GELİR - 5'Lİ GELİR GRUBU
df["gelir"] = pd.to_numeric(
    df["hanenin aylık toplam net geliri (5'li gelir grubu)"],
    errors="coerce"
)

df["log_gelir"] = np.log1p(df["gelir"])

# 6) MODEL DATAFRAME
model_df = pd.concat(
    [
        df[["online_saglik", "cinsiyet_kadin", "log_gelir"]],
        yas_dummy,
        egitim_dummy
    ],
    axis=1
)

model_df = model_df.apply(pd.to_numeric, errors="coerce")

print("Dropna öncesi satır sayısı:", len(model_df))
print("\nEksik değer sayıları:")
print(model_df.isna().sum())

model_df = model_df.dropna()

print("\nDropna sonrası satır sayısı:", len(model_df))

# 7) X ve y
y = model_df["online_saglik"]
X = model_df.drop(columns=["online_saglik"])

X = sm.add_constant(X)

X = X.astype(float)
y = y.astype(float)

# 8) KONTROLLER
print("\nBağımlı değişken dağılımı:")
print(y.value_counts())

print("\nEğitim grubu dağılımı:")
print(df["egitim_grup"].value_counts(dropna=False))

print("\nGelir dağılımı:")
print(df["gelir"].value_counts(dropna=False).sort_index())

print("\nModel değişkenleri:")
print(X.columns)

# 9) PROBIT MODEL
probit_model = sm.Probit(y, X)
result = probit_model.fit()

print(result.summary().as_text())
# Out:
# Dropna öncesi satır sayısı: 24771
#
# Eksik değer sayıları:
# online_saglik        4033
# cinsiyet_kadin          0
# log_gelir               0
# yas_31-45               0
# yas_46-60               0
# yas_60+                 0
# egitim_Doktora          0
# egitim_Orta_Lise        0
# egitim_Universite       0
# dtype: int64
#
# Dropna sonrası satır sayısı: 20738
#
# Bağımlı değişken dağılımı:
# online_saglik
# 1.0    13463
# 0.0     7275
# Name: count, dtype: int64
#
# Eğitim grubu dağılımı:
# egitim_grup
# Orta_Lise          17384
# Universite          5158
# Ilkokul_ve_alti     2130
# Doktora               99
# Name: count, dtype: int64
#
# Gelir dağılımı:
# gelir
# 1    4740
# 2    4945
# 3    5096
# 4    4921
# 5    5069
# Name: count, dtype: int64
#
# Model değişkenleri:
# Index(['const', 'cinsiyet_kadin', 'log_gelir', 'yas_31-45', 'yas_46-60',
#        'yas_60+', 'egitim_Doktora', 'egitim_Orta_Lise', 'egitim_Universite'],
#       dtype='str')
# Optimization terminated successfully.
#          Current function value: 0.578188
#          Iterations 5
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:          online_saglik   No. Observations:                20738
# Model:                         Probit   Df Residuals:                    20729
# Method:                           MLE   Df Model:                            8
# Date:                Fri, 15 May 2026   Pseudo R-squ.:                  0.1077
# Time:                        10:15:06   Log-Likelihood:                -11990.
# converged:                       True   LL-Null:                       -13437.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -1.2846      0.067    -19.114      0.000      -1.416      -1.153
# cinsiyet_kadin        0.2013      0.019     10.596      0.000       0.164       0.239
# log_gelir             0.4324      0.026     16.363      0.000       0.381       0.484
# yas_31-45             0.0435      0.024      1.845      0.065      -0.003       0.090
# yas_46-60            -0.3247      0.025    -13.107      0.000      -0.373      -0.276
# yas_60+              -0.6851      0.035    -19.619      0.000      -0.754      -0.617
# egitim_Doktora        1.7193      0.169     10.165      0.000       1.388       2.051
# egitim_Orta_Lise      1.0155      0.057     17.937      0.000       0.905       1.126
# egitim_Universite     1.6883      0.061     27.863      0.000       1.570       1.807
# =====================================================================================

# %%
summary_text = result.summary().as_text()

print(summary_text)
# Out:
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:          online_saglik   No. Observations:                20738
# Model:                         Probit   Df Residuals:                    20729
# Method:                           MLE   Df Model:                            8
# Date:                Fri, 15 May 2026   Pseudo R-squ.:                  0.1077
# Time:                        10:15:23   Log-Likelihood:                -11990.
# converged:                       True   LL-Null:                       -13437.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -1.2846      0.067    -19.114      0.000      -1.416      -1.153
# cinsiyet_kadin        0.2013      0.019     10.596      0.000       0.164       0.239
# log_gelir             0.4324      0.026     16.363      0.000       0.381       0.484
# yas_31-45             0.0435      0.024      1.845      0.065      -0.003       0.090
# yas_46-60            -0.3247      0.025    -13.107      0.000      -0.373      -0.276
# yas_60+              -0.6851      0.035    -19.619      0.000      -0.754      -0.617
# egitim_Doktora        1.7193      0.169     10.165      0.000       1.388       2.051
# egitim_Orta_Lise      1.0155      0.057     17.937      0.000       0.905       1.126
# egitim_Universite     1.6883      0.061     27.863      0.000       1.570       1.807
# =====================================================================================

# %%
# 10) MARGINAL EFFECTS
marginal = result.get_margeff()
print(marginal.summary())
# Out:
#        Probit Marginal Effects
# =====================================
# Dep. Variable:          online_saglik
# Method:                          dydx
# At:                           overall
# =====================================================================================
#                        dy/dx    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# cinsiyet_kadin        0.0661      0.006     10.680      0.000       0.054       0.078
# log_gelir             0.1420      0.009     16.683      0.000       0.125       0.159
# yas_31-45             0.0143      0.008      1.845      0.065      -0.001       0.029
# yas_46-60            -0.1066      0.008    -13.267      0.000      -0.122      -0.091
# yas_60+              -0.2249      0.011    -20.181      0.000      -0.247      -0.203
# egitim_Doktora        0.5645      0.055     10.235      0.000       0.456       0.673
# egitim_Orta_Lise      0.3334      0.018     18.359      0.000       0.298       0.369
# egitim_Universite     0.5543      0.019     29.422      0.000       0.517       0.591
# =====================================================================================

# %%
# =====================================================
# ETİCARET İLAÇ ALIŞVERİŞİ - PROBIT MODEL
# GELİR = 5'Lİ GELİR GRUBU
# =====================================================

import pandas as pd
import numpy as np
import statsmodels.api as sm

# -----------------------------------------------------
# BAĞIMLI DEĞİŞKEN
# -----------------------------------------------------

df["eticaret_ilac"] = df["eticaret ilaç alışverişi"].replace({
    "Evet": 1,
    "Hayır": 0,
    "evet": 1,
    "hayır": 0,
    1: 1,
    2: 0,
    0: 0
})

# -----------------------------------------------------
# CİNSİYET
# -----------------------------------------------------

df["cinsiyet_kadin"] = df["cinsiyet"].replace({
    "Erkek": 0,
    "Kadın": 1,
    "erkek": 0,
    "kadın": 1,
    1: 0,
    2: 1
})

# -----------------------------------------------------
# YAŞ
# -----------------------------------------------------

df["yas"] = pd.to_numeric(
    df["yaş"],
    errors="coerce"
)

df["yas_grup"] = pd.cut(
    df["yas"],
    bins=[14, 30, 45, 60, 120],
    labels=[
        "15-30",
        "31-45",
        "46-60",
        "60+"
    ]
)

yas_dummy = pd.get_dummies(
    df["yas_grup"],
    prefix="yas"
)

# REFERANS
yas_dummy = yas_dummy.drop(
    columns=["yas_15-30"],
    errors="ignore"
)

# -----------------------------------------------------
# EĞİTİM
# -----------------------------------------------------

df["egitim_sayi"] = pd.to_numeric(
    df["eğitim"],
    errors="coerce"
)

def egitim_kategori(x):

    # REFERANS
    if x in [1, 2]:
        return "Ilkokul_ve_alti"

    # ORTAOKUL / LİSE
    elif x in [3, 4]:
        return "Ortaokul_Lise"

    # ÜNİVERSİTE
    elif x in [51, 511, 512]:
        return "Universite"

    # ÜNİVERSİTEÜSTÜ
    elif x in [52, 53]:
        return "Universiteustu"

    else:
        return np.nan

df["egitim_grup"] = df["egitim_sayi"].apply(
    egitim_kategori
)

egitim_dummy = pd.get_dummies(
    df["egitim_grup"],
    prefix="egitim"
)

# REFERANS
egitim_dummy = egitim_dummy.drop(
    columns=["egitim_Ilkokul_ve_alti"],
    errors="ignore"
)

# -----------------------------------------------------
# GELİR
# 5'Lİ GELİR GRUBU
# -----------------------------------------------------

df["gelir"] = pd.to_numeric(
    df["hanenin aylık toplam net geliri (5'li gelir grubu)"],
    errors="coerce"
)

# LOG GELİR
df["log_gelir"] = np.log1p(df["gelir"])

# -----------------------------------------------------
# MODEL DATAFRAME
# -----------------------------------------------------

model_df = pd.concat(
    [
        df[
            [
                "eticaret_ilac",
                "cinsiyet_kadin",
                "log_gelir"
            ]
        ],
        yas_dummy,
        egitim_dummy
    ],
    axis=1
)

# -----------------------------------------------------
# SAYISALA ÇEVİR
# -----------------------------------------------------

model_df = model_df.apply(
    pd.to_numeric,
    errors="coerce"
)

# -----------------------------------------------------
# EKSİKLERİ TEMİZLE
# -----------------------------------------------------

model_df = model_df.dropna()

# -----------------------------------------------------
# X ve y
# -----------------------------------------------------

y = model_df["eticaret_ilac"]

X = model_df.drop(
    columns=["eticaret_ilac"]
)

# CONSTANT
X = sm.add_constant(X)

# FLOAT
X = X.astype(float)
y = y.astype(float)

# -----------------------------------------------------
# MODEL
# -----------------------------------------------------

probit_model = sm.Probit(y, X)

result = probit_model.fit()

# -----------------------------------------------------
# SONUÇLAR
# -----------------------------------------------------

summary_text = result.summary().as_text()

print(summary_text)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.362888
#          Iterations 6
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:          eticaret_ilac   No. Observations:                 8835
# Model:                         Probit   Df Residuals:                     8826
# Method:                           MLE   Df Model:                            8
# Date:                Sat, 16 May 2026   Pseudo R-squ.:                 0.03380
# Time:                        18:33:05   Log-Likelihood:                -3206.1
# converged:                       True   LL-Null:                       -3318.3
# Covariance Type:            nonrobust   LLR p-value:                 4.650e-44
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -1.9654      0.111    -17.746      0.000      -2.182      -1.748
# cinsiyet_kadin            0.1673      0.035      4.725      0.000       0.098       0.237
# log_gelir                 0.2795      0.060      4.660      0.000       0.162       0.397
# yas_31-45                 0.1414      0.040      3.571      0.000       0.064       0.219
# yas_46-60                 0.2348      0.055      4.286      0.000       0.127       0.342
# yas_60+                   0.4148      0.116      3.582      0.000       0.188       0.642
# egitim_Ortaokul_Lise      0.0354      0.073      0.486      0.627      -0.107       0.178
# egitim_Universite         0.3714      0.073      5.122      0.000       0.229       0.513
# egitim_Universiteustu     0.4262      0.097      4.374      0.000       0.235       0.617
# =========================================================================================
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["eticaret_ilac"] = df["eticaret ilaç alışverişi"].replace({
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["cinsiyet_kadin"] = df["cinsiyet"].replace({
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas"] = pd.to_numeric(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grup"] = pd.cut(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:72: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_sayi"] = pd.to_numeric(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:98: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_grup"] = df["egitim_sayi"].apply(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir"] = pd.to_numeric(
# C:\Users\dilara\AppData\Local\Temp\ipykernel_29596\686088388.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["log_gelir"] = np.log1p(df["gelir"])

# %%
# -----------------------------------------------------
# MARJİNAL ETKİLER
# -----------------------------------------------------

marginal = result.get_margeff()

print(marginal.summary())
# Out:
#        Probit Marginal Effects
# =====================================
# Dep. Variable:          eticaret_ilac
# Method:                          dydx
# At:                           overall
# =========================================================================================
#                            dy/dx    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# cinsiyet_kadin            0.0332      0.007      4.727      0.000       0.019       0.047
# log_gelir                 0.0554      0.012      4.659      0.000       0.032       0.079
# yas_31-45                 0.0281      0.008      3.572      0.000       0.013       0.043
# yas_46-60                 0.0466      0.011      4.289      0.000       0.025       0.068
# yas_60+                   0.0823      0.023      3.584      0.000       0.037       0.127
# egitim_Ortaokul_Lise      0.0070      0.014      0.486      0.627      -0.021       0.035
# egitim_Universite         0.0737      0.014      5.126      0.000       0.046       0.102
# egitim_Universiteustu     0.0846      0.019      4.378      0.000       0.047       0.122
# =========================================================================================
