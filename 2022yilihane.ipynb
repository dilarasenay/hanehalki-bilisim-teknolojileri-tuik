# %%
import pandas as pd 
df= pd.read_excel(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\HBTKA_HANE_2022_EVAM.xlsx" )
df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  KAPSAMICI_KAPSAMDISI  BT_BILG_MASAUSTU  \
# 0          2022      10012                     1                 2
# 1          2022      10014                     1                 2
# 2          2022      10017                     1                 2
# 3          2022      10018                     1                 2
# 4          2022      10019                     1                 2
#
#    BT_BILG_DIZUSTU  BT_TABLET  BT_TEL_CEP  BT_DIGER_CIHAZ  \
# 0                2          2           1               2
# 1                1          2           1               1
# 2                1          1           1               2
# 3                1          2           1               2
# 4                1          1           1               1
#
#    HANE_INTERNET_ERISIM_DURUMU  hane_aylik_gelir_grp_20  HHB IBBS_1  \
# 0                            1                       12    1    TR1
# 1                            1                       12    3    TR1
# 2                            1                       19    2    TR1
# 3                            1                       16    3    TR1
# 4                            1                       16    2    TR1
#
#    hane_faktor
# 0  3960.165238
# 1  2403.691000
# 2  3361.134507
# 3  3243.679528
# 4  1241.614271

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13454 entries, 0 to 13453
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REFERANS_YIL                 13454 non-null  int64
#  1   BULTEN_NO                    13454 non-null  int64
#  2   KAPSAMICI_KAPSAMDISI         13454 non-null  int64
#  3   BT_BILG_MASAUSTU             13454 non-null  int64
#  4   BT_BILG_DIZUSTU              13454 non-null  int64
#  5   BT_TABLET                    13454 non-null  int64
#  6   BT_TEL_CEP                   13454 non-null  int64
#  7   BT_DIGER_CIHAZ               13454 non-null  int64
#  8   HANE_INTERNET_ERISIM_DURUMU  13454 non-null  int64
#  9   hane_aylik_gelir_grp_20      13454 non-null  int64
#  10  HHB                          13454 non-null  int64
#  11  IBBS_1                       13454 non-null  str
#  12  hane_faktor                  13454 non-null  float64
# dtypes: float64(1), int64(11), str(1)
# memory usage: 1.3 MB

# %%
df.rename(columns={"REFERANS_YIL": "referans yıl"}, inplace=True)
df.rename(columns={"BULTEN_NO": "bülten no"}, inplace=True)
df.rename(columns={"BT_BILG_MASAUSTU": "hanede masaüstü bilgisayar var mı"}, inplace=True)
df.rename(columns={"BT_BILG_DIZUSTU": "hanede dizüstü bilgisayar var mı"}, inplace=True)
df.rename(columns={"BT_TABLET": "hanede tablet var mı"}, inplace=True)
df.rename(columns={"HANE_INTERNET_ERISIM_DURUMU": "hane internet erişim durumu"}, inplace=True)
df.rename(columns={"hane_aylik_gelir_grp_20": "hanenin aylık toplam net geliri (20'li gelir grubu)"}, inplace=True)
df.rename(columns={"HHB": "hane büyüklüğü"}, inplace=True)
df.rename(columns={"IBBS_1": "istatistiki bölge birimleri sınıflaması (düzey 1)"}, inplace=True)
df.rename(columns={"MAH_DEG_L1": "hanehalkı adresinin kır veya kent olma durumu"}, inplace=True)
df.rename(columns={"hane_faktor": "hane ağırlık katsayısı"}, inplace=True)
df.rename(columns={"BT_TEL_CEP": "hanede cep telefonu var mı"}, inplace=True)
df.rename(columns={"BT_DIGER_CIHAZ": "hanede diğer cihazlar var mı"}, inplace=True)
df.rename(columns={"KAPSAMICI_KAPSAMDISI": "kapsam içi/dışı"}, inplace=True)

# %%
df.head()
# Out:
#    referans yıl  bülten no  kapsam içi/dışı  \
# 0          2022      10012                1
# 1          2022      10014                1
# 2          2022      10017                1
# 3          2022      10018                1
# 4          2022      10019                1
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 2
# 1                                  2                                 1
# 2                                  2                                 1
# 3                                  2                                 1
# 4                                  2                                 1
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     2                           1
# 2                     1                           1
# 3                     2                           1
# 4                     1                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             2                            1
# 3                             2                            1
# 4                             1                            1
#
#    hanenin aylık toplam net geliri (20'li gelir grubu)  hane büyüklüğü  \
# 0                                                   12               1
# 1                                                   12               3
# 2                                                   19               2
# 3                                                   16               3
# 4                                                   16               2
#
#   istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                               TR1             3960.165238
# 1                                               TR1             2403.691000
# 2                                               TR1             3361.134507
# 3                                               TR1             3243.679528
# 4                                               TR1             1241.614271

# %%
df.to_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\hane bilişim temiz veriler\2022temizhanebilişim.csv", index=False)
aa = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\hane bilişim temiz veriler\2022temizhanebilişim.csv")
aa.head()
# Out:
#    referans yıl  bülten no  kapsam içi/dışı  \
# 0          2022      10012                1
# 1          2022      10014                1
# 2          2022      10017                1
# 3          2022      10018                1
# 4          2022      10019                1
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 2
# 1                                  2                                 1
# 2                                  2                                 1
# 3                                  2                                 1
# 4                                  2                                 1
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     2                           1
# 2                     1                           1
# 3                     2                           1
# 4                     1                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             2                            1
# 3                             2                            1
# 4                             1                            1
#
#    hanenin aylık toplam net geliri (20'li gelir grubu)  hane büyüklüğü  \
# 0                                                   12               1
# 1                                                   12               3
# 2                                                   19               2
# 3                                                   16               3
# 4                                                   16               2
#
#   istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                               TR1             3960.165238
# 1                                               TR1             2403.691000
# 2                                               TR1             3361.134507
# 3                                               TR1             3243.679528
# 4                                               TR1             1241.614271

# %% [markdown]
# # 2022 yılı croas tabloları

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2022.csv")
df.head()
# Out:
#    referans yıl  bülten no  fert no  yaş  cinsiyet  yakınlık durumu  \
# 0          2022      10012        1   44         1                1
# 1          2022      10014        1   61         1                1
# 2          2022      10014        2   57         2                2
# 3          2022      10014        3   16         2                3
# 4          2022      10017        1   41         2                2
#
#    fert no.1  eğitim  okuma yazma durumu  çalışma durumu  ...  \
# 0          3       2                 NaN               1  ...
# 1          3       2                 NaN               3  ...
# 2          1       2                 NaN               3  ...
# 3          3       3                 NaN               3  ...
# 4          3      53                 NaN               1  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 2
# 1                                  2                                 1
# 2                                  2                                 1
# 3                                  2                                 1
# 4                                  2                                 1
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     2                           1
# 2                     2                           1
# 3                     2                           1
# 4                     1                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             1                            1
# 3                             1                            1
# 4                             2                            1
#
#    hanenin aylık toplam net geliri (20'li gelir grubu)  hane büyüklüğü  \
# 0                                                 12                 1
# 1                                                 12                 3
# 2                                                 12                 3
# 3                                                 12                 3
# 4                                                 19                 2
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             3960.165238
# 1                                                TR1             2403.691000
# 2                                                TR1             2403.691000
# 3                                                TR1             2403.691000
# 4                                                TR1             3361.134507
#
# [5 rows x 160 columns]

# %%
# =========================================================
# ONLINE SAĞLIK HİZMETİ KULLANIMI (VAR / YOK)
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# VAR
online_var = df[df["sağlık bilgisi arama"] == 1]["cinsiyet"] \
    .value_counts()

online_var_yuzde = round(
    df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# YOK
online_yok = df[df["sağlık bilgisi arama"] == 2]["cinsiyet"] \
    .value_counts()

online_yok_yuzde = round(
    df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# TABLO
online_tablo = pd.DataFrame({

    "online sağlık hizmeti kullanımı var": [
        online_var.get(2, 0),
        online_var.get(1, 0),
        online_var.sum()
    ],

    "online sağlık hizmeti kullanımı var yüzde": [
        online_var_yuzde.get(2, 0),
        online_var_yuzde.get(1, 0),
        100
    ],

    "online sağlık hizmeti kullanımı yok": [
        online_yok.get(2, 0),
        online_yok.get(1, 0),
        online_yok.sum()
    ],

    "online sağlık hizmeti kullanımı yok yüzde": [
        online_yok_yuzde.get(2, 0),
        online_yok_yuzde.get(1, 0),
        100
    ]

},

index=["kadın", "erkek", "toplam"]

)

display(online_tablo)
# Out:
#         online sağlık hizmeti kullanımı var  \
# kadın                                  7715
# erkek                                  7389
# toplam                                15104
#
#         online sağlık hizmeti kullanımı var yüzde  \
# kadın                                       51.08
# erkek                                       48.92
# toplam                                     100.00
#
#         online sağlık hizmeti kullanımı yok  \
# kadın                                  3913
# erkek                                  5040
# toplam                                 8953
#
#         online sağlık hizmeti kullanımı yok yüzde
# kadın                                       43.71
# erkek                                       56.29
# toplam                                     100.00

# %%
# =========================================================
# ETİCARET İLAÇ ALIŞVERİŞİ (VAR / YOK)
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# VAR
eticaret_var = df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"] \
    .value_counts()

eticaret_var_yuzde = round(
    df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# YOK
eticaret_yok = df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"] \
    .value_counts()

eticaret_yok_yuzde = round(
    df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# TABLO
eticaret_tablo = pd.DataFrame({

    "eticaret ilaç alışverişi var": [
        eticaret_var.get(2, 0),
        eticaret_var.get(1, 0),
        eticaret_var.sum()
    ],

    "eticaret ilaç alışverişi var yüzde": [
        eticaret_var_yuzde.get(2, 0),
        eticaret_var_yuzde.get(1, 0),
        100
    ],

    "eticaret ilaç alışverişi yok": [
        eticaret_yok.get(2, 0),
        eticaret_yok.get(1, 0),
        eticaret_yok.sum()
    ],

    "eticaret ilaç alışverişi yok yüzde": [
        eticaret_yok_yuzde.get(2, 0),
        eticaret_yok_yuzde.get(1, 0),
        100
    ]

},

index=["kadın", "erkek", "toplam"]

)

display(eticaret_tablo)
# Out:
#         eticaret ilaç alışverişi var  eticaret ilaç alışverişi var yüzde  \
# kadın                            589                                56.2
# erkek                            459                                43.8
# toplam                          1048                               100.0
#
#         eticaret ilaç alışverişi yok  eticaret ilaç alışverişi yok yüzde
# kadın                           3982                               48.79
# erkek                           4180                               51.21
# toplam                          8162                              100.00

# %%
# =========================================================
# ETİCARET İLAÇ ALIŞVERİŞİ (VAR / YOK)
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# VAR
eticaret_var = df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"] \
    .value_counts()

eticaret_var_yuzde = round(
    df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# YOK
eticaret_yok = df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"] \
    .value_counts()

eticaret_yok_yuzde = round(
    df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
    .value_counts(normalize=True) * 100,
    2
)

# TABLO
eticaret_tablo = pd.DataFrame({

    "eticaret ilaç alışverişi var": [
        eticaret_var.get(2, 0),
        eticaret_var.get(1, 0),
        eticaret_var.sum()
    ],

    "eticaret ilaç alışverişi var yüzde": [
        eticaret_var_yuzde.get(2, 0),
        eticaret_var_yuzde.get(1, 0),
        100
    ],

    "eticaret ilaç alışverişi yok": [
        eticaret_yok.get(2, 0),
        eticaret_yok.get(1, 0),
        eticaret_yok.sum()
    ],

    "eticaret ilaç alışverişi yok yüzde": [
        eticaret_yok_yuzde.get(2, 0),
        eticaret_yok_yuzde.get(1, 0),
        100
    ]

},

index=["kadın", "erkek", "toplam"]

)

display(eticaret_tablo)
# Out:
#         eticaret ilaç alışverişi var  eticaret ilaç alışverişi var yüzde  \
# kadın                            589                                56.2
# erkek                            459                                43.8
# toplam                          1048                               100.0
#
#         eticaret ilaç alışverişi yok  eticaret ilaç alışverişi yok yüzde
# kadın                           3982                               48.79
# erkek                           4180                               51.21
# toplam                          8162                              100.00

# %%
import pandas as pd

# ======================================================
# GELİR GRUBU
# ======================================================

df = df.sort_values("hane gelir aylık").reset_index(drop=True)

df["gelir_grup"] = pd.qcut(
    df.index,
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# ======================================================
# ONLINE SAĞLIK HİZMETİ KULLANIMI
# 1 = var, 2 = yok
# cinsiyet: 1 = erkek, 2 = kadın
# ======================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt_df = df[df["gelir_grup"] == gelir]

    var_df = alt_df[alt_df["sağlık bilgisi arama"] == 1]
    yok_df = alt_df[alt_df["sağlık bilgisi arama"] == 2]

    var_cinsiyet_yuzde = var_df["cinsiyet"].value_counts(normalize=True) * 100
    yok_cinsiyet_yuzde = yok_df["cinsiyet"].value_counts(normalize=True) * 100

    sonuc.append({
        "yıl": 2021,
        "gelir": gelir,

        "var kadın": round(var_cinsiyet_yuzde.get(2, 0), 2),
        "var erkek": round(var_cinsiyet_yuzde.get(1, 0), 2),
        "var toplam": len(var_df),

        "yok kadın": round(yok_cinsiyet_yuzde.get(2, 0), 2),
        "yok erkek": round(yok_cinsiyet_yuzde.get(1, 0), 2),
        "yok toplam": len(yok_df)
    })

gelir_online_saglik_2021 = pd.DataFrame(sonuc)

# ======================================================
# EN ALT FREKANS SATIRI
# kadın/erkek/toplam hepsi frekans
# ======================================================

toplam_var = df[df["sağlık bilgisi arama"] == 1]
toplam_yok = df[df["sağlık bilgisi arama"] == 2]

toplam_var_cinsiyet = toplam_var["cinsiyet"].value_counts()
toplam_yok_cinsiyet = toplam_yok["cinsiyet"].value_counts()

toplam_satiri = pd.DataFrame([{
    "yıl": 2021,
    "gelir": "frekans",

    "var kadın": toplam_var_cinsiyet.get(2, 0),
    "var erkek": toplam_var_cinsiyet.get(1, 0),
    "var toplam": len(toplam_var),

    "yok kadın": toplam_yok_cinsiyet.get(2, 0),
    "yok erkek": toplam_yok_cinsiyet.get(1, 0),
    "yok toplam": len(toplam_yok)
}])

gelir_online_saglik_2021= pd.concat(
    [gelir_online_saglik_2021, toplam_satiri],
    ignore_index=True
)

display(gelir_online_saglik_2021)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 7
#       3 # ======================================================
#       4 # GELİR GRUBU
#       5 # ======================================================
#       6
# ----> 7 df = df.sort_values("hane gelir aylık").reset_index(drop=True)
#       8
#       9 df["gelir_grup"] = pd.qcut(
#      10     df.index,
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\frame.py:8347, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8343             )
#    8344         elif by:
#    8345             # len(by) == 1
#    8346
# -> 8347             k = self._get_label_or_level_values(by[0], axis=axis)
#    8348
#    8349             # need to rewrap column in Series to apply key function
#    8350             if key is not None:
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'hane gelir aylık'

# %%
df["hanenin aylık toplam net geliri (20'li gelir grubu)"].value_counts()
# Out:
# hanenin aylık toplam net geliri (20'li gelir grubu)
# 4     1759
# 11    1699
# 10    1627
# 7     1599
# 14    1563
# 5     1549
# 17    1528
# 12    1521
# 2     1510
# 15    1505
# 18    1492
# 8     1422
# 9     1393
# 6     1393
# 3     1392
# 19    1384
# 13    1337
# 16    1325
# 20    1315
# 1     1268
# Name: count, dtype: int64

# %%
df["hanenin aylık toplam net geliri (20'li gelir grubu)"].value_counts().sort_index()
# Out:
# hanenin aylık toplam net geliri (20'li gelir grubu)
# 1     1268
# 2     1510
# 3     1392
# 4     1759
# 5     1549
# 6     1393
# 7     1599
# 8     1422
# 9     1393
# 10    1627
# 11    1699
# 12    1521
# 13    1337
# 14    1563
# 15    1505
# 16    1325
# 17    1528
# 18    1492
# 19    1384
# 20    1315
# Name: count, dtype: int64

# %%
df["hanenin aylık toplam net geliri (20'li gelir grubu)"] \
    .value_counts() \
    .sort_index()
# Out:
# hanenin aylık toplam net geliri (20'li gelir grubu)
# 1     1268
# 2     1510
# 3     1392
# 4     1759
# 5     1549
# 6     1393
# 7     1599
# 8     1422
# 9     1393
# 10    1627
# 11    1699
# 12    1521
# 13    1337
# 14    1563
# 15    1505
# 16    1325
# 17    1528
# 18    1492
# 19    1384
# 20    1315
# Name: count, dtype: int64

# %%
# =========================================================
# ONLINE SAĞLIK HİZMETİ KULLANIMI
# GELİR GRUBU x CİNSİYET TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# 20'Lİ GELİRİ 5'LİYE ÇEVİR
# =========================================================

df["gelir_grup"] = pd.cut(
    df["hanenin aylık toplam net geliri (20'li gelir grubu)"],
    bins=[0, 4, 8, 12, 16, 20],
    labels=[1, 2, 3, 4, 5]
)

# =========================================================
# SONUÇLAR
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt_df = df[df["gelir_grup"] == gelir]

    # VAR
    toplam_var = alt_df[
        alt_df["sağlık bilgisi arama"] == 1
    ]

    var_cinsiyet = toplam_var["cinsiyet"] \
        .value_counts(normalize=True) * 100

    # YOK
    toplam_yok = alt_df[
        alt_df["sağlık bilgisi arama"] == 2
    ]

    yok_cinsiyet = toplam_yok["cinsiyet"] \
        .value_counts(normalize=True) * 100

    sonuc.append({

        "yıl": 2022,

        "gelir": gelir,

        "var kadın":
            round(var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(toplam_var),

        "yok kadın":
            round(yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(toplam_yok)

    })

# =========================================================
# TOPLAM / FREKANS SATIRI
# =========================================================

toplam_var_df = df[df["sağlık bilgisi arama"] == 1]
toplam_yok_df = df[df["sağlık bilgisi arama"] == 2]

toplam_var_cinsiyet = toplam_var_df["cinsiyet"].value_counts()
toplam_yok_cinsiyet = toplam_yok_df["cinsiyet"].value_counts()

toplam_satiri = pd.DataFrame([{

    "yıl": 2022,

    "gelir": "frekans",

    "var kadın":
        toplam_var_cinsiyet.get(2, 0),

    "var erkek":
        toplam_var_cinsiyet.get(1, 0),

    "var toplam":
        len(toplam_var_df),

    "yok kadın":
        toplam_yok_cinsiyet.get(2, 0),

    "yok erkek":
        toplam_yok_cinsiyet.get(1, 0),

    "yok toplam":
        len(toplam_yok_df)

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_online_saglik_2022 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_online_saglik_2022)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_20992\1533901286.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir_grup"] = pd.cut(
#     yıl    gelir  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2022        1      53.10      46.90        1533      45.03      54.97
# 1  2022        2      51.93      48.07        2694      44.65      55.35
# 2  2022        3      51.33      48.67        3117      44.24      55.76
# 3  2022        4      49.86      50.14        3596      41.19      58.81
# 4  2022        5      50.65      49.35        4164      42.29      57.71
# 5  2022  frekans    7715.00    7389.00       15104    3913.00    5040.00
#
#    yok toplam
# 0        2014
# 1        2038
# 2        2066
# 3        1544
# 4        1291
# 5        8953

# %%
df["gelir_grup"].value_counts()
# Out:
# gelir_grup
# 3    6240
# 2    5963
# 1    5929
# 4    5730
# 5    5719
# Name: count, dtype: int64

# %%
df["gelir_grup"] = pd.qcut(
    df["hanenin aylık toplam net geliri (20'li gelir grubu)"],
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# %%
df["gelir_grup"].value_counts().sort_index()
# Out:
# gelir_grup
# 1    5929
# 2    5963
# 3    6240
# 4    5730
# 5    5719
# Name: count, dtype: int64

# %%
df["gelir_grup"] = (
    (df["hanenin aylık toplam net geliri (20'li gelir grubu)"] - 1) // 4
) + 1

df["gelir_grup"].value_counts().sort_index()
# Out:
# gelir_grup
# 1    5929
# 2    5963
# 3    6240
# 4    5730
# 5    5719
# Name: count, dtype: int64

# %%
df["gelir_grup"] = pd.qcut(
    df["hanenin aylık toplam net geliri (20'li gelir grubu)"],
    q=5,
    labels=[1, 2, 3, 4, 5]
)

df["gelir_grup"].value_counts().sort_index()
# Out:
# gelir_grup
# 1    5929
# 2    5963
# 3    6240
# 4    5730
# 5    5719
# Name: count, dtype: int64

# %%
import pandas as pd

# önce 20'li gelir grubuna göre sırala
df = df.sort_values(
    "hanenin aylık toplam net geliri (20'li gelir grubu)"
).reset_index(drop=True)

# sonra satır sırasına göre 5 eşit gruba böl
df["gelir_grup"] = pd.qcut(
    df.index,
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# kontrol
df["gelir_grup"].value_counts().sort_index()
# Out:
# gelir_grup
# 1    5917
# 2    5916
# 3    5916
# 4    5916
# 5    5916
# Name: count, dtype: int64

# %%
# =========================================================
# GELİR GRUBU x SAĞLIK BİLGİSİ ARAMA
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# 20'Lİ GELİR GRUBUNU 5 EŞİT GRUBA ÇEVİR
# =========================================================

df = df.sort_values(
    "hanenin aylık toplam net geliri (20'li gelir grubu)"
).reset_index(drop=True)

df["gelir_grup"] = pd.qcut(
    df.index,
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt = df[df["gelir_grup"] == gelir]

    # SAĞLIK BİLGİSİ ARAMA VAR
    saglik_var = alt[
        alt["sağlık bilgisi arama"] == 1
    ]

    saglik_var_cinsiyet = (
        saglik_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # SAĞLIK BİLGİSİ ARAMA YOK
    saglik_yok = alt[
        alt["sağlık bilgisi arama"] == 2
    ]

    saglik_yok_cinsiyet = (
        saglik_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2022,

        "gelir": gelir,

        # VAR
        "var kadın":
            round(saglik_var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(saglik_var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(saglik_var),

        # YOK
        "yok kadın":
            round(saglik_yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(saglik_yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(saglik_yok)

    })

# =========================================================
# FREKANS SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2022,

    "gelir": "frekans",

    "var kadın":
        df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["sağlık bilgisi arama"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["sağlık bilgisi arama"] == 1]),

    "yok kadın":
        df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["sağlık bilgisi arama"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["sağlık bilgisi arama"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_saglik_2022 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_saglik_2022)
# Out:
#     yıl    gelir  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2022        1      53.14      46.86        1528      45.03      54.97
# 1  2022        2      51.84      48.16        2670      44.76      55.24
# 2  2022        3      51.06      48.94        2938      44.37      55.63
# 3  2022        4      50.41      49.59        3682      41.10      58.90
# 4  2022        5      50.47      49.53        4286      42.28      57.72
# 5  2022  frekans    7715.00    7389.00       15104    3913.00    5040.00
#
#    yok toplam
# 0        2014
# 1        2024
# 2        1954
# 3        1613
# 4        1348
# 5        8953

# %%
df["gelir_grup"].value_counts()
# Out:
# gelir_grup
# 1    5917
# 2    5916
# 3    5916
# 4    5916
# 5    5916
# Name: count, dtype: int64

# %%
# =========================================================
# GELİR GRUBU x ETİCARETTEN İLAÇ ALIŞVERİŞİ
# 2022 → 20'Lİ GELİRİ 5 EŞİT PARÇAYA BÖL
# =========================================================

import pandas as pd

# =========================================================
# 20'Lİ GELİR GRUBUNU 5 EŞİT GRUBA ÇEVİR
# =========================================================

df = df.sort_values(
    "hanenin aylık toplam net geliri (20'li gelir grubu)"
).reset_index(drop=True)

df["gelir_grup"] = pd.qcut(
    df.index,
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt = df[df["gelir_grup"] == gelir]

    # ETİCARETTEN İLAÇ ALIŞVERİŞİ VAR
    eticaret_var = alt[
        alt["eticaretten ilaç alışverişi"] == 1
    ]

    eticaret_var_cinsiyet = (
        eticaret_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # ETİCARETTEN İLAÇ ALIŞVERİŞİ YOK
    eticaret_yok = alt[
        alt["eticaret ilaç alışverişi"] == 2
    ]

    eticaret_yok_cinsiyet = (
        eticaret_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2022,

        "gelir": gelir,

        # VAR
        "var kadın":
            round(eticaret_var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(eticaret_var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(eticaret_var),

        # YOK
        "yok kadın":
            round(eticaret_yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(eticaret_yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(eticaret_yok)

    })

# =========================================================
# FREKANS SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2022,

    "gelir": "frekans",

    "var kadın":
        df[df["eticaretten ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["eticaretten ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["eticaretten ilaç alışverişi"] == 1]),

    "yok kadın":
        df[df["eticaretten ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["eticaretten ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["eticaretten ilaç alışverişi"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_eticaret_2022 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_eticaret_2022)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_21740\1832130389.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["gelir_grup"] = pd.qcut(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'eticaretten ilaç alışverişi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 34
#      30     alt = df[df["gelir_grup"] == gelir]
#      31
#      32     # ETİCARETTEN İLAÇ ALIŞVERİŞİ VAR
#      33     eticaret_var = alt[
# ---> 34         alt["eticaretten ilaç alışverişi"] == 1
#      35     ]
#      36
#      37     eticaret_var_cinsiyet = (
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\dilara\hanehalki-bilisim-teknolojileri-tuik\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'eticaretten ilaç alışverişi'

# %%
# =========================================================
# GELİR GRUBU x ETİCARET İLAÇ ALIŞVERİŞİ
# 2022 → 20'Lİ GELİRİ 5 EŞİT GRUBA BÖL
# =========================================================

import pandas as pd

# =========================================================
# 20'Lİ GELİR GRUBUNU 5 EŞİT GRUBA ÇEVİR
# =========================================================

df = df.sort_values(
    "hanenin aylık toplam net geliri (20'li gelir grubu)"
).reset_index(drop=True)

df["gelir_grup"] = pd.qcut(
    df.index,
    q=5,
    labels=[1, 2, 3, 4, 5]
)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for gelir in [1, 2, 3, 4, 5]:

    alt = df[df["gelir_grup"] == gelir]

    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    eticaret_var = alt[
        alt["eticaret ilaç alışverişi"] == 1
    ]

    eticaret_var_cinsiyet = (
        eticaret_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    eticaret_yok = alt[
        alt["eticaret ilaç alışverişi"] == 2
    ]

    eticaret_yok_cinsiyet = (
        eticaret_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2022,

        "gelir": gelir,

        # VAR
        "var kadın":
            round(eticaret_var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(eticaret_var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(eticaret_var),

        # YOK
        "yok kadın":
            round(eticaret_yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(eticaret_yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(eticaret_yok)

    })

# =========================================================
# FREKANS SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2022,

    "gelir": "frekans",

    "var kadın":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["eticaret ilaç alışverişi"] == 1]),

    "yok kadın":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["eticaret ilaç alışverişi"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

gelir_eticaret_2022 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(gelir_eticaret_2022)
# Out:
#     yıl    gelir  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2022        1      63.04      36.96          46      51.99      48.01
# 1  2022        2      65.17      34.83          89      50.25      49.75
# 2  2022        3      56.00      44.00         150      48.88      51.12
# 3  2022        4      55.06      44.94         247      47.72      52.28
# 4  2022        5      54.65      45.35         516      48.24      51.76
# 5  2022  frekans     589.00     459.00        1048    3982.00    4180.00
#
#    yok toplam
# 0         577
# 1        1186
# 2        1514
# 3        2043
# 4        2842
# 5        8162

# %%
df["gelir_grup"].value_counts()
# Out:
# gelir_grup
# 1    5917
# 2    5916
# 3    5916
# 4    5916
# 5    5916
# Name: count, dtype: int64

# %%
# =========================================================
# YAŞ GRUBU x SAĞLIK BİLGİSİ ARAMA
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

df["yas_grup"] = pd.cut(
    df["yaş"],
    bins=[15, 30, 45, 60, 100],
    labels=["15-30", "31-45", "46-60", "60+"],
    include_lowest=True
)

sonuc = []

for yas in ["15-30", "31-45", "46-60", "60+"]:

    alt = df[df["yas_grup"] == yas]

    # SAĞLIK BİLGİSİ ARAMA VAR
    saglik_var = alt[alt["sağlık bilgisi arama"] == 1]

    saglik_var_cinsiyet = (
        saglik_var["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # SAĞLIK BİLGİSİ ARAMA YOK
    saglik_yok = alt[alt["sağlık bilgisi arama"] == 2]

    saglik_yok_cinsiyet = (
        saglik_yok["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({
        "yıl": 2017,
        "yaş": yas,

        "var kadın": round(saglik_var_cinsiyet.get(2, 0), 2),
        "var erkek": round(saglik_var_cinsiyet.get(1, 0), 2),
        "var toplam": len(saglik_var),

        "yok kadın": round(saglik_yok_cinsiyet.get(2, 0), 2),
        "yok erkek": round(saglik_yok_cinsiyet.get(1, 0), 2),
        "yok toplam": len(saglik_yok)
    })

# =========================================================
# TOPLAM SATIRI - FREKANS
# =========================================================

toplam_satiri = pd.DataFrame([{
    "yıl": 2017,
    "yaş": "toplam",

    "var kadın": df[df["sağlık bilgisi arama"] == 1]["cinsiyet"].value_counts().get(2, 0),
    "var erkek": df[df["sağlık bilgisi arama"] == 1]["cinsiyet"].value_counts().get(1, 0),
    "var toplam": len(df[df["sağlık bilgisi arama"] == 1]),

    "yok kadın": df[df["sağlık bilgisi arama"] == 2]["cinsiyet"].value_counts().get(2, 0),
    "yok erkek": df[df["sağlık bilgisi arama"] == 2]["cinsiyet"].value_counts().get(1, 0),
    "yok toplam": len(df[df["sağlık bilgisi arama"] == 2])
}])

yas_saglik_2017 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(yas_saglik_2017)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_11852\1184860868.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grup"] = pd.cut(
#     yıl     yaş  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2017   15-30      53.77      46.23        5321      42.38      57.62
# 1  2017   31-45      51.95      48.05        5940      43.79      56.21
# 2  2017   46-60      47.07      52.93        3085      45.29      54.71
# 3  2017     60+      41.69      58.31         758      42.44      57.56
# 4  2017  toplam    7715.00    7389.00       15104    3913.00    5040.00
#
#    yok toplam
# 0        2369
# 1        2631
# 2        2782
# 3        1171
# 4        8953

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2022.csv")
df.head()
# Out:
#    referans yıl  bülten no  fert no  yaş  cinsiyet  yakınlık durumu  \
# 0          2022      10012        1   44         1                1
# 1          2022      10014        1   61         1                1
# 2          2022      10014        2   57         2                2
# 3          2022      10014        3   16         2                3
# 4          2022      10017        1   41         2                2
#
#    fert no.1  eğitim  okuma yazma durumu  çalışma durumu  ...  \
# 0          3       2                 NaN               1  ...
# 1          3       2                 NaN               3  ...
# 2          1       2                 NaN               3  ...
# 3          3       3                 NaN               3  ...
# 4          3      53                 NaN               1  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 2
# 1                                  2                                 1
# 2                                  2                                 1
# 3                                  2                                 1
# 4                                  2                                 1
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     2                           1
# 2                     2                           1
# 3                     2                           1
# 4                     1                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             1                            1
# 3                             1                            1
# 4                             2                            1
#
#    hanenin aylık toplam net geliri (20'li gelir grubu)  hane büyüklüğü  \
# 0                                                 12                 1
# 1                                                 12                 3
# 2                                                 12                 3
# 3                                                 12                 3
# 4                                                 19                 2
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             3960.165238
# 1                                                TR1             2403.691000
# 2                                                TR1             2403.691000
# 3                                                TR1             2403.691000
# 4                                                TR1             3361.134507
#
# [5 rows x 160 columns]

# %%
# =========================================================
# YAŞ x ETİCARET İLAÇ ALIŞVERİŞİ
# CİNSİYETE GÖRE FREKANS + YÜZDE TABLOSU
# =========================================================

import pandas as pd

# =========================================================
# YAŞ GRUPLARI
# =========================================================

df["yas_grup"] = pd.cut(
    df["yaş"],
    bins=[15, 30, 45, 60, 100],
    labels=["15-30", "31-45", "46-60", "60+"],
    include_lowest=True
)

# =========================================================
# TABLO
# =========================================================

sonuc = []

for yas in ["15-30", "31-45", "46-60", "60+"]:

    alt = df[df["yas_grup"] == yas]

    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    var_df = alt[
        alt["eticaret ilaç alışverişi"] == 1
    ]

    var_cinsiyet = (
        var_df["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    yok_df = alt[
        alt["eticaret ilaç alışverişi"] == 2
    ]

    yok_cinsiyet = (
        yok_df["cinsiyet"]
        .value_counts(normalize=True) * 100
    )

    sonuc.append({

        "yıl": 2024,

        "yaş": yas,

        # VAR
        "var kadın":
            round(var_cinsiyet.get(2, 0), 2),

        "var erkek":
            round(var_cinsiyet.get(1, 0), 2),

        "var toplam":
            len(var_df),

        # YOK
        "yok kadın":
            round(yok_cinsiyet.get(2, 0), 2),

        "yok erkek":
            round(yok_cinsiyet.get(1, 0), 2),

        "yok toplam":
            len(yok_df)

    })

# =========================================================
# TOPLAM SATIRI
# =========================================================

toplam_satiri = pd.DataFrame([{

    "yıl": 2024,

    "yaş": "toplam",

    "var kadın":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "var erkek":
        df[df["eticaret ilaç alışverişi"] == 1]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "var toplam":
        len(df[df["eticaret ilaç alışverişi"] == 1]),

    "yok kadın":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(2, 0),

    "yok erkek":
        df[df["eticaret ilaç alışverişi"] == 2]["cinsiyet"]
        .value_counts()
        .get(1, 0),

    "yok toplam":
        len(df[df["eticaret ilaç alışverişi"] == 2])

}])

# =========================================================
# BİRLEŞTİR
# =========================================================

yas_eticaret = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(yas_eticaret)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_31676\2876047059.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["yas_grup"] = pd.cut(
#     yıl     yaş  var kadın  var erkek  var toplam  yok kadın  yok erkek  \
# 0  2024   15-30      59.44      40.56         360      52.96      47.04
# 1  2024   31-45      58.03      41.97         498      47.97      52.03
# 2  2024   46-60      47.24      52.76         163      38.06      61.94
# 3  2024     60+      33.33      66.67          27      37.75      62.25
# 4  2024  toplam     589.00     459.00        1048    3982.00    4180.00
#
#    yok toplam
# 0        3727
# 1        3233
# 2        1051
# 3         151
# 4        8162

# %%
import pandas as pd
import numpy as np

# =========================================================
# EĞİTİM KATEGORİLERİ (2017)
# =========================================================

def egitim_kategori(x):

    if pd.isna(x):
        return None

    x = int(x)

    # İLKOKUL VE ALTI
    if x in [1, 2]:
        return "ilkokulvealtı"

    # ORTAOKUL / LİSE
    elif x in [3, 4]:
        return "ortaokul/lise"

    # ÜNİVERSİTE
    elif x in [51, 52]:
        return "üniversite"

    # ÜNİVERSİTE ÜSTÜ
    elif x in [53]:
        return "üniversiteüstü"

    else:
        return None


# =========================================================
# EĞİTİM GRUBU OLUŞTUR
# =========================================================

df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)

# =========================================================
# SONUÇ LİSTESİ
# =========================================================

sonuc = []

for grup in [
    "ilkokulvealtı",
    "ortaokul/lise",
    "üniversite",
    "üniversiteüstü"
]:

    temp = df[df["egitim_grup"] == grup]

    # =====================================================
    # SAĞLIK BİLGİSİ ARAMA = VAR
    # =====================================================

    var_df = temp[temp["sağlık bilgisi arama"] == 1]

    var_kadin = round(
        (var_df["cinsiyet"].value_counts(normalize=True).get(2, 0)) * 100,
        2
    )

    var_erkek = round(
        (var_df["cinsiyet"].value_counts(normalize=True).get(1, 0)) * 100,
        2
    )

    var_toplam = len(var_df)

    # =====================================================
    # SAĞLIK BİLGİSİ ARAMA = YOK
    # =====================================================

    yok_df = temp[temp["sağlık bilgisi arama"] == 2]

    yok_kadin = round(
        (yok_df["cinsiyet"].value_counts(normalize=True).get(2, 0)) * 100,
        2
    )

    yok_erkek = round(
        (yok_df["cinsiyet"].value_counts(normalize=True).get(1, 0)) * 100,
        2
    )

    yok_toplam = len(yok_df)

    sonuc.append({
        "yıl": 2017,
        "eğitim": grup,
        "var kadın": var_kadin,
        "var erkek": var_erkek,
        "var toplam": var_toplam,
        "yok kadın": yok_kadin,
        "yok erkek": yok_erkek,
        "yok toplam": yok_toplam
    })

# =========================================================
# TOPLAM SATIRI
# =========================================================

var_all = df[df["sağlık bilgisi arama"] == 1]
yok_all = df[df["sağlık bilgisi arama"] == 2]

toplam_satiri = pd.DataFrame([{
    "yıl": 2017,
    "eğitim": "toplam",

    "var kadın": len(var_all[var_all["cinsiyet"] == 2]),
    "var erkek": len(var_all[var_all["cinsiyet"] == 1]),
    "var toplam": len(var_all),

    "yok kadın": len(yok_all[yok_all["cinsiyet"] == 2]),
    "yok erkek": len(yok_all[yok_all["cinsiyet"] == 1]),
    "yok toplam": len(yok_all)
}])

# =========================================================
# BİRLEŞTİR
# =========================================================

egitim_saglik_2017 = pd.concat(
    [pd.DataFrame(sonuc), toplam_satiri],
    ignore_index=True
)

display(egitim_saglik_2017)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_30828\2140524588.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["egitim_grup"] = df["eğitim"].apply(egitim_kategori)
#     yıl          eğitim  var kadın  var erkek  var toplam  yok kadın  \
# 0  2017   ilkokulvealtı      58.20      41.80        2885      53.40
# 1  2017   ortaokul/lise      48.52      51.48        7380      35.26
# 2  2017      üniversite      47.44      52.56         390      23.75
# 3  2017  üniversiteüstü      45.71      54.29          70      14.29
# 4  2017          toplam    7715.00    7389.00       15104    3913.00
#
#    yok erkek  yok toplam
# 0      46.60        4197
# 1      64.74        3732
# 2      76.25          80
# 3      85.71           7
# 4    5040.00        8953

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\ferthane\yıl2022.csv")
df.head()
# Out:
#    referans yıl  bülten no  fert no  yaş  cinsiyet  yakınlık durumu  \
# 0          2022      10012        1   44         1                1
# 1          2022      10014        1   61         1                1
# 2          2022      10014        2   57         2                2
# 3          2022      10014        3   16         2                3
# 4          2022      10017        1   41         2                2
#
#    fert no.1  eğitim  okuma yazma durumu  çalışma durumu  ...  \
# 0          3       2                 NaN               1  ...
# 1          3       2                 NaN               3  ...
# 2          1       2                 NaN               3  ...
# 3          3       3                 NaN               3  ...
# 4          3      53                 NaN               1  ...
#
#    hanede masaüstü bilgisayar var mı  hanede dizüstü bilgisayar var mı  \
# 0                                  2                                 2
# 1                                  2                                 1
# 2                                  2                                 1
# 3                                  2                                 1
# 4                                  2                                 1
#
#    hanede tablet var mı  hanede cep telefonu var mı  \
# 0                     2                           1
# 1                     2                           1
# 2                     2                           1
# 3                     2                           1
# 4                     1                           1
#
#    hanede diğer cihazlar var mı  hane internet erişim durumu  \
# 0                             2                            1
# 1                             1                            1
# 2                             1                            1
# 3                             1                            1
# 4                             2                            1
#
#    hanenin aylık toplam net geliri (20'li gelir grubu)  hane büyüklüğü  \
# 0                                                 12                 1
# 1                                                 12                 3
# 2                                                 12                 3
# 3                                                 12                 3
# 4                                                 19                 2
#
#    istatistiki bölge birimleri sınıflaması (düzey 1)  hane ağırlık katsayısı
# 0                                                TR1             3960.165238
# 1                                                TR1             2403.691000
# 2                                                TR1             2403.691000
# 3                                                TR1             2403.691000
# 4                                                TR1             3361.134507
#
# [5 rows x 160 columns]

# %%
import pandas as pd
import numpy as np

# =========================================================
# YIL
# =========================================================
YIL = 2025


# =========================================================
# TÜM YILLARA UYUMLU EĞİTİM KATEGORİSİ
# =========================================================
def egitim_kategori(x):

    try:
        x = int(x)
    except:
        return np.nan

    # -------------------------------------------------
    # İLKOKUL VE ALTI
    # -------------------------------------------------
    if x in [0, 1, 2]:
        return "ilkokulvealtı"

    # -------------------------------------------------
    # ORTAOKUL / LİSE
    # -------------------------------------------------
    elif x in [3, 4]:
        return "ortaokul/lise"

    # -------------------------------------------------
    # ÜNİVERSİTE
    # -------------------------------------------------
    elif x in [5, 6, 51, 52, 511, 512]:
        return "üniversite"

    # -------------------------------------------------
    # ÜNİVERSİTE ÜSTÜ
    # -------------------------------------------------
    elif x in [7, 53]:
        return "üniversiteüstü"

    else:
        return np.nan


# =========================================================
# EĞİTİM GRUBU
# =========================================================
df["eğitim_grup"] = df["eğitim"].apply(egitim_kategori)


# =========================================================
# ETİCARET İLAÇ ALIŞVERİŞİ
# =========================================================
df["ilac_alisveris"] = df["eticaret ilaç alışverişi"].replace({
    "Evet": 1,
    "Hayır": 0,
    1: 1,
    2: 0
})


# =========================================================
# SONUÇ TABLOSU
# =========================================================
sonuc = []

egitim_sirasi = [
    "ilkokulvealtı",
    "ortaokul/lise",
    "üniversite",
    "üniversiteüstü"
]

for egitim in egitim_sirasi:

    alt = df[df["eğitim_grup"] == egitim]

    # =====================================================
    # ETİCARET İLAÇ ALIŞVERİŞİ VAR
    # =====================================================
    var_df = alt[alt["ilac_alisveris"] == 1]

    var_kadin = (var_df["cinsiyet"] == 2).sum()
    var_erkek = (var_df["cinsiyet"] == 1).sum()
    var_toplam = len(var_df)

    # =====================================================
    # ETİCARET İLAÇ ALIŞVERİŞİ YOK
    # =====================================================
    yok_df = alt[alt["ilac_alisveris"] == 0]

    yok_kadin = (yok_df["cinsiyet"] == 2).sum()
    yok_erkek = (yok_df["cinsiyet"] == 1).sum()
    yok_toplam = len(yok_df)

    # =====================================================
    # SATIR EKLE
    # =====================================================
    sonuc.append({

        "yıllar": YIL,
        "eğitim": egitim,

        "kadın_var": var_kadin,
        "erkek_var": var_erkek,
        "toplam_var": var_toplam,

        "kadın_yok": yok_kadin,
        "erkek_yok": yok_erkek,
        "toplam_yok": yok_toplam
    })


# =========================================================
# DATAFRAME
# =========================================================
tablo = pd.DataFrame(sonuc)


# =========================================================
# TOPLAM SATIRI
# =========================================================
toplam_satiri = pd.DataFrame([{

    "yıllar": "",
    "eğitim": "toplam",

    "kadın_var": tablo["kadın_var"].sum(),
    "erkek_var": tablo["erkek_var"].sum(),
    "toplam_var": tablo["toplam_var"].sum(),

    "kadın_yok": tablo["kadın_yok"].sum(),
    "erkek_yok": tablo["erkek_yok"].sum(),
    "toplam_yok": tablo["toplam_yok"].sum()

}])


# =========================================================
# FİNAL TABLO
# =========================================================
final_tablo = pd.concat(
    [tablo, toplam_satiri],
    ignore_index=True
)


# =========================================================
# GÖSTER
# =========================================================
display(final_tablo)


# =========================================================
# EXCEL AKTAR
# =========================================================
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_14668\1077536611.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["eğitim_grup"] = df["eğitim"].apply(egitim_kategori)
# C:\Users\dilara\AppData\Local\Temp\ipykernel_14668\1077536611.py:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ilac_alisveris"] = df["eticaret ilaç alışverişi"].replace({
#   yıllar          eğitim  kadın_var  erkek_var  toplam_var  kadın_yok  \
# 0   2025   ilkokulvealtı         34         28          62        387
# 1   2025   ortaokul/lise        195        163         358       1900
# 2   2025      üniversite        353        260         613       1677
# 3   2025  üniversiteüstü          7          8          15         18
# 4                 toplam        589        459        1048       3982
#
#    erkek_yok  toplam_yok
# 0        341         728
# 1       2118        4018
# 2       1696        3373
# 3         25          43
# 4       4180        8162

# %%
import pandas as pd

# =========================================================
# YIL
# =========================================================
YIL = 2020


# =========================================================
# RANDEVU ALMA DEĞİŞKENİ
# =========================================================
df["randevu_alma"] = df["randevu alma (e-nabız,mhrs vb.)"].replace({
    "Evet": 1,
    "Hayır": 0,
    1: 1,
    2: 0
})


# =========================================================
# VAR
# =========================================================
var_df = df[df["randevu_alma"] == 1]

var_toplam = len(var_df)

var_kadin = round(
    ((var_df["cinsiyet"] == 2).sum() / var_toplam) * 100,
    2
)

var_erkek = round(
    ((var_df["cinsiyet"] == 1).sum() / var_toplam) * 100,
    2
)


# =========================================================
# YOK
# =========================================================
yok_df = df[df["randevu_alma"] == 0]

yok_toplam = len(yok_df)

yok_kadin = round(
    ((yok_df["cinsiyet"] == 2).sum() / yok_toplam) * 100,
    2
)

yok_erkek = round(
    ((yok_df["cinsiyet"] == 1).sum() / yok_toplam) * 100,
    2
)


# =========================================================
# TABLO
# =========================================================
final_tablo = pd.DataFrame([{

    "yıllar": YIL,

    "kadın_var": var_kadin,
    "erkek_var": var_erkek,
    "toplam_var": var_toplam,

    "kadın_yok": yok_kadin,
    "erkek_yok": yok_erkek,
    "toplam_yok": yok_toplam

}])


# =========================================================
# GÖSTER
# =========================================================
display(final_tablo)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_14668\566767331.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["randevu_alma"] = df["randevu alma (e-nabız,mhrs vb.)"].replace({
#    yıllar  kadın_var  erkek_var  toplam_var  kadın_yok  erkek_yok  toplam_yok
# 0    2020      46.49      53.51       14938      51.37      48.63        9119

# %%
import pandas as pd

# =========================================================
# YIL
# =========================================================
YIL = 2020


# =========================================================
# SAĞLIK SONUÇLARINI ALMA DEĞİŞKENİ
# =========================================================
df["saglik_sonuc"] = df["sağlık sonuçlarını almak"].replace({
    "Evet": 1,
    "Hayır": 0,
    1: 1,
    2: 0
})


# =========================================================
# VAR
# =========================================================
var_df = df[df["saglik_sonuc"] == 1]

var_toplam = len(var_df)

var_kadin = round(
    ((var_df["cinsiyet"] == 2).sum() / var_toplam) * 100,
    2
)

var_erkek = round(
    ((var_df["cinsiyet"] == 1).sum() / var_toplam) * 100,
    2
)


# =========================================================
# YOK
# =========================================================
yok_df = df[df["saglik_sonuc"] == 0]

yok_toplam = len(yok_df)

yok_kadin = round(
    ((yok_df["cinsiyet"] == 2).sum() / yok_toplam) * 100,
    2
)

yok_erkek = round(
    ((yok_df["cinsiyet"] == 1).sum() / yok_toplam) * 100,
    2
)


# =========================================================
# TABLO
# =========================================================
final_tablo = pd.DataFrame([{

    "yıllar": YIL,

    "kadın_var": var_kadin,
    "erkek_var": var_erkek,
    "toplam_var": var_toplam,

    "kadın_yok": yok_kadin,
    "erkek_yok": yok_erkek,
    "toplam_yok": yok_toplam

}])


# =========================================================
# GÖSTER
# =========================================================
display(final_tablo)
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_6984\398983725.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["saglik_sonuc"] = df["sağlık sonuçlarını almak"].replace({
#    yıllar  kadın_var  erkek_var  toplam_var  kadın_yok  erkek_yok  toplam_yok
# 0    2020      45.41      54.59       16729      55.02      44.98        7328
