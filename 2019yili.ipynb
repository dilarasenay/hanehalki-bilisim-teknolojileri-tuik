# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\fert_2019.csv" , sep=";")

df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  FERTNO  CEVAPLILIK_DURUM_FERT  YAS  CINSIYET  \
# 0          2019      17848       2                    1.0   43         2
# 1          2019      10011       1                    1.0   68         2
# 2          2019      10011       2                    1.0   73         1
# 3          2019      10012       1                    1.0   56         1
# 4          2019      10012       2                    1.0   51         2
#
#    OKUMA_YAZMA  OKUL_BITEN  CALISMA_DURUM  CALISMA_SAHIP_IS  ...  \
# 0          1.0         2.0            1.0               NaN  ...
# 1          1.0         2.0            3.0               2.0  ...
# 2          1.0         2.0            3.0               2.0  ...
# 3          1.0         2.0            3.0               2.0  ...
# 4          1.0         2.0            3.0               2.0  ...
#
#    EYETENEK_BLGMOBIL_UYGLM_YUKLM  EYETENEK_BLGMOBIL_SISTEM_DEG  \
# 0                            1.0                           1.0
# ...

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 23171     16
# 23296     16
# 23391     16
# 25323     16
# 23436     15
#           ..
# 252910     1
# 256510     1
# 257010     1
# 257210     1
# 257410     1
# Name: count, Length: 13561, dtype: int64
