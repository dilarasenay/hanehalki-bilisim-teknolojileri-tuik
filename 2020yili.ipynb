# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\FERT_2020.xlsx")

df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  FERTNO  CEVAPLILIK_DURUM_FERT  YAS  CINSIYET  \
# 0          2020      10011       1                    1.0   61         1
# 1          2020      10011       2                    1.0   55         2
# 2          2020      10011       3                    1.0   27         2
# 3          2020      10012       1                    1.0   51         1
# 4          2020      10012       2                    1.0   48         2
#
#    OKUMA_YAZMA  OKUL_BITEN  CALISMA_DURUM  CALISMA_SAHIP_IS  ...  \
# 0          1.0       512.0            1.0               NaN  ...
# 1          1.0       512.0            3.0               1.0  ...
# 2          1.0       512.0            1.0               NaN  ...
# 3          1.0         4.0            1.0               NaN  ...
# 4          1.0         2.0            3.0               2.0  ...
#
#    SOSMED_RKLM_ETIC_SENET  Unnamed: 73  AKILLI_TEL_KSL_KULLANIM  \
# 0                     NaN          NaN                      1.0
# ...

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 22227    18
# 25832    18
# 24799    16
# 22081    15
# 24545    15
#          ..
# 27505     1
# 27508     1
# 27535     1
# 27536     1
# 27538     1
# Name: count, Length: 15103, dtype: int64
