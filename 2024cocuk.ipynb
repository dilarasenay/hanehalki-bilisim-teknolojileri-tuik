# %%
import pandas as pd 

df = pd.read_excel(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\cbtka_2024_tr.xlsx")
df.head()
# Out:
#     BULTEN_NO  FERTNO  CINSIYET  DOGUM_TARIH_GUN  DOGUM_TARIH_AY  \
# 0  1000068682       3         2             29.0            11.0
# 1  1000610731       2         1             19.0             1.0
# 2  1000610731       5         2              3.0            12.0
# 3  1000610731       6         2             12.0             7.0
# 4  1000952935       5         2             13.0             3.0
#
#    DOGUM_TARIH_YIL  YAS  DOGUM_YER DOGUM_YER_ULKE_KOD  UYRUK  ...  \
# 0             2008   15          1                NaN      1  ...
# 1             2010   14          1                NaN      1  ...
# 2             2008   15          1                NaN      1  ...
# 3             2011   12          1                NaN      1  ...
# 4             2013   11          1                NaN      1  ...
#
#   DIJITALOYUN_FAZLA_ZAMAN_EBVEYN  DIJITALOYUN_OYNAMAMA_MUTSUZ  \
# 0                            NaN                          NaN
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#        bülten no  fert no  cinsiyet  doğum tarihi gün  doğum tarihi ay  \
# 0     1000068682        3         2              29.0             11.0
# 1     1000610731        2         1              19.0              1.0
# 2     1000610731        5         2               3.0             12.0
# 3     1000610731        6         2              12.0              7.0
# 4     1000952935        5         2              13.0              3.0
# ...          ...      ...       ...               ...              ...
# 7067  5496588756        3         2              16.0              3.0
# 7068  5496588756        4         2               3.0              9.0
# 7069  5496588756        5         2              13.0             10.0
# 7070  5497885698        5         2               7.0              6.0
# 7071  5499264058        4         1               1.0              6.0
#
#       doğum tarihi yıl  yaş  doğum yeri doğum yeri ülke kodu  uyruk  \
# ...

# %%
df.rename(columns={"BULTEN_NO": "bülten no"}, inplace=True)
df.rename(columns={"FERTNO": "fert no"}, inplace=True)
df.rename(columns={"CINSIYET": "cinsiyet"}, inplace=True)
df.rename(columns={"DOGUM_TARIH_GUN": "doğum tarihi gün"}, inplace=True)
df.rename(columns={"DOGUM_TARIH_AY": "doğum tarihi ay"}, inplace=True)
df.rename(columns={"DOGUM_TARIH_YIL": "doğum tarihi yıl"}, inplace=True)
df.rename(columns={"YAS": "yaş"}, inplace=True)
df.rename(columns={"DOGUM_YER": "doğum yeri"}, inplace=True)
df.rename(columns={"DOGUM_YER_ULKE_KOD": "doğum yeri ülke kodu"}, inplace=True)
df.rename(columns={"UYRUK": "uyruk"}, inplace=True)
df.rename(columns={"UYRUK_ULKE_KOD": "uyruk ülke kodu"}, inplace=True)

# %%
df.rename(columns={"HHSORUMLU_YAKINLIK": "yakınlık durumu"}, inplace=True)
df.rename(columns={"OKUL_BITEN": "eğitim"}, inplace=True)
df.rename(columns={"OKUMA_YAZMA": "okuma yazma durumu"}, inplace=True)
df.rename(columns={"EGITIM_DEVAM": "eğitime devam etme durumu"}, inplace=True)
df.rename(columns={"OKUL_DEVAM": "devam edilen okul"}, inplace=True)
df.rename(columns={"KENDI_KUL_MASAUSTU": "çocuğun kendi masaüstü bilgisayarı"}, inplace=True)
df.rename(columns={"KENDI_KUL_DIZUSTU": "çocuğun kendi dizüstü bilgisayarı"}, inplace=True)
df.rename(columns={"KENDI_KUL_TABLET": "çocuğun kendi tableti"}, inplace=True)
df.rename(columns={"KENDI_KUL_CEP": "çocuğun kendi cep telefonu"}, inplace=True)
df.rename(columns={"KENDI_KUL_SAAT": "çocuğun kendi akıllı saati"}, inplace=True)
df.rename(columns={"KENDI_KUL_OYN_KNSL": "çocuğun kendi oyun konsolu"}, inplace=True)
df.rename(columns={"BILG_OYUN_SIKLIK": "bilgisayar oyunu oynama sıklığı"}, inplace=True)
df.rename(columns={"SPOR_YAPMA_SIKLIK": "spor yapma sıklığı"}, inplace=True)
df.rename(columns={"KITAP_OKUMA_SIKLIK": "kitap okuma sıklığı"}, inplace=True)
df.rename(columns={"DIGER_HOBI_SIKLIK": "diğer hobiler sıklığı"}, inplace=True)
df.rename(columns={"EGLENME_DISARI_SIKLIK": "eğlenmek için dışarı çıkma sıklığı"}, inplace=True)
df.rename(columns={"INT_GEZINME_SIKLIK": "internette gezinme sıklığı"}, inplace=True)
df.rename(columns={"TV_IZLEME_SIKLIK": "tv programları izleme sıklığı"}, inplace=True)
df.rename(columns={"CEP_KULLANIM": "cep telefonu kullanım durumu"}, inplace=True)
df.rename(columns={"CEP_KULLANIM_SIKLIK": "cep telefonu kullanım sıklığı"}, inplace=True)

# %%
df.rename(columns={"CEP_SURE_HAFTAICI": "hafta içi cep telefonu ortalama kullanımı"}, inplace=True)
df.rename(columns={"CEP_SURE_HAFTASONU": "hafta sonu cep telefonu ortalama kullanımı"}, inplace=True)
df.rename(columns={"CEP_AMAC_KONUSMA": "cep telefonu konuşma amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_MESAJ": "cep telefonu mesaj amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_SOSYALMEDYA": "cep telefonu sosyal medya amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_OYUN": "cep telefonu oyun amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_FILM": "cep telefonu film amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_MUZK": "cep telefonu müzik amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_INTERNET": "cep telefonu internette gezinme amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_DERS": "cep telefonu ders/ödev amaçlı"}, inplace=True)
df.rename(columns={"CEP_AMAC_DERS_ONLINE": "cep telefonu online derse katılma amaçlı"}, inplace=True)
df.rename(columns={"CEP_KONT_YARIMSAAT": "çocuk yarım saatte bir telefonunu kontrol ediyor"}, inplace=True)

# %%
df.rename(columns={"CEP_KONT_UYKU_ONCESI": ""}, inplace=True)
df.rename(columns={"CEP_KONT_UYANINCA": ""}, inplace=True)
df.rename(columns={"CEP_KONT_TV_IZLERKEN": ""}, inplace=True)
df.rename(columns={"CEP_KONT_TOPLU_YEMEK": ""}, inplace=True)
df.rename(columns={"BILGISAYAR_KULLANIM": ""}, inplace=True)
df.rename(columns={"BILG_TUR_MASAUSTU": ""}, inplace=True)
df.rename(columns={"BILG_TUR_DIZUSTU": ""}, inplace=True)
df.rename(columns={"BILG_TUR_TABLET	": ""}, inplace=True)

# %%
df
# Out:
#        bülten no  fert no  cinsiyet  doğum tarihi gün  doğum tarihi ay  \
# 0     1000068682        3         2              29.0             11.0
# 1     1000610731        2         1              19.0              1.0
# 2     1000610731        5         2               3.0             12.0
# 3     1000610731        6         2              12.0              7.0
# 4     1000952935        5         2              13.0              3.0
# ...          ...      ...       ...               ...              ...
# 7067  5496588756        3         2              16.0              3.0
# 7068  5496588756        4         2               3.0              9.0
# 7069  5496588756        5         2              13.0             10.0
# 7070  5497885698        5         2               7.0              6.0
# 7071  5499264058        4         1               1.0              6.0
#
#       doğum tarihi yıl  yaş  doğum yeri doğum yeri ülke kodu  uyruk  \
# ...
