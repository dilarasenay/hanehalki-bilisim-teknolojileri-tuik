# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\hbtka_2025_fert.xlsx")

df.head()
# Out:
#    BULTEN_NO  REFERANS_YIL  GORUSME_YONTEM_FERT  CINSIYET  YAS  \
# 0      10011          2025                    3         1   65
# 1      10011          2025                    3         2   60
# 2      10012          2025                    3         1   49
# 3      10012          2025                    3         2   45
# 4      10013          2025                    3         1   70
#
#    HHSORUMLU_YAKINLIK  OKUL_BITEN  OKUMA_YAZMA  CALISMA_DURUM  \
# 0                   1         512          NaN              3
# 1                   2         512          NaN              3
# 2                   1         512          NaN              1
# 3                   2         512          NaN              1
# 4                   1           4          NaN              3
#
#    CALISMAMA_NEDEN  ...  INT_KBILGI_KORU_IZINVRMEME  INT_KBILGI_KORU_WEBKNTRL  \
# 0              5.0  ...                         1.0                       2.0
# 1              5.0  ...                         1.0                       1.0
# 2              NaN  ...                         1.0                       2.0
# 3              NaN  ...                         1.0                       1.0
# 4              5.0  ...                         2.0                       2.0
#
#    INT_KBILGI_KORU_WEB_TALP INT_KBILGI_CEREZ_SNR  INT_KBILGI_RKLM_ENDS  \
# 0                       2.0                  2.0                1131.0
# 1                       2.0                  2.0                1131.0
# 2                       2.0                  2.0                1130.0
# 3                       2.0                  2.0                1130.0
# 4                       2.0                  2.0                1222.0
#
#   INT_KBILGI_ETKNLIK_SNR  INT_HESAP_AC  INT_HESAP_SIL  INT_HESAP_SIL_SORUN  \
# 0                    2.0           1.0            2.0                  NaN
# 1                    2.0           1.0            2.0                  NaN
# 2                    2.0           1.0            2.0                  NaN
# 3                    2.0           1.0            2.0                  NaN
# 4                    2.0           2.0            NaN                  NaN
#
#    fert_faktor
# 0  3045.660009
# 1  3045.660009
# 2  2295.674589
# 3  2295.674589
# 4  3813.920274
#
# [5 rows x 157 columns]

# %%
df = pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25493 entries, 0 to 25492
# Columns: 157 entries, BULTEN_NO to fert_faktor
# dtypes: float64(143), int64(12), str(2)
# memory usage: 30.5 MB

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 18336     10
# 20863      8
# 23969      8
# 10938      7
# 13105      7
#           ..
# 236010     1
# 237310     1
# 238510     1
# 240610     1
# 240810     1
# Name: count, Length: 11924, dtype: int64

# %%
df.rename(columns={"BULTEN_NO": "bülten no"}, inplace=True)

# %%
df["REFERANS_YIL"].value_counts()
# Out:
# REFERANS_YIL
# 2025    25493
# Name: count, dtype: int64

# %%
df.rename(columns={"REFERANS_YIL": "referans yıl"}, inplace=True)

# %%
df.head()
# Out:
#    bülten no  referans yıl  GORUSME_YONTEM_FERT  CINSIYET  YAS  \
# 0      10011          2025                    3         1   65
# 1      10011          2025                    3         2   60
# 2      10012          2025                    3         1   49
# 3      10012          2025                    3         2   45
# 4      10013          2025                    3         1   70
#
#    HHSORUMLU_YAKINLIK  OKUL_BITEN  OKUMA_YAZMA  CALISMA_DURUM  \
# 0                   1         512          NaN              3
# 1                   2         512          NaN              3
# 2                   1         512          NaN              1
# 3                   2         512          NaN              1
# 4                   1           4          NaN              3
#
#    CALISMAMA_NEDEN  ...  INT_KBILGI_KORU_IZINVRMEME  INT_KBILGI_KORU_WEBKNTRL  \
# 0              5.0  ...                         1.0                       2.0
# 1              5.0  ...                         1.0                       1.0
# 2              NaN  ...                         1.0                       2.0
# 3              NaN  ...                         1.0                       1.0
# 4              5.0  ...                         2.0                       2.0
#
#    INT_KBILGI_KORU_WEB_TALP INT_KBILGI_CEREZ_SNR  INT_KBILGI_RKLM_ENDS  \
# 0                       2.0                  2.0                1131.0
# 1                       2.0                  2.0                1131.0
# 2                       2.0                  2.0                1130.0
# 3                       2.0                  2.0                1130.0
# 4                       2.0                  2.0                1222.0
#
#   INT_KBILGI_ETKNLIK_SNR  INT_HESAP_AC  INT_HESAP_SIL  INT_HESAP_SIL_SORUN  \
# 0                    2.0           1.0            2.0                  NaN
# 1                    2.0           1.0            2.0                  NaN
# 2                    2.0           1.0            2.0                  NaN
# 3                    2.0           1.0            2.0                  NaN
# 4                    2.0           2.0            NaN                  NaN
#
#    fert_faktor
# 0  3045.660009
# 1  3045.660009
# 2  2295.674589
# 3  2295.674589
# 4  3813.920274
#
# [5 rows x 157 columns]

# %%
df["GORUSME_YONTEM_FERT"].value_counts()
# Out:
# GORUSME_YONTEM_FERT
# 3    18385
# 1     7108
# Name: count, dtype: int64

# %%
df.rename(columns={"GORUSME_YONTEM_FERT": "fert no"}, inplace=True)

# %%
df.rename(columns={"CINSIYET": "cinsiyet"}, inplace=True)

# %%
df.rename(columns={"YAS": "yaş"}, inplace=True)

# %%
df.rename(columns={"HHSORUMLU_YAKINLIK": "yakınlık durumu"}, inplace=True)

# %%
df.rename(columns={"OKUL_BITEN": "eğitim"}, inplace=True)

# %%
df.rename(columns={"OKUMA_YAZMA": "okuma yazma durumu"}, inplace=True)

# %%
df.rename(columns={"CALISMA_DURUM": "çalışma durumu"}, inplace=True)

# %%
df.rename(columns={"CALISMAMA_NEDEN": "çalışmama nedeni"}, inplace=True)

# %%
df.rename(columns={"ISTEKI_DURUM": "işteki durumu"}, inplace=True)

# %%
df.rename(columns={"ISCO08": "uluslararası meslek"}, inplace=True)

# %%
df.rename(columns={"DOGUM_YER": "doğduğu ülke"}, inplace=True)

# %%
df.rename(columns={"DOGUM_YER_ULKE_KOD": "doğduğu ülke kodu"}, inplace=True)

# %%
df.rename(columns={"UYRUK": "uyruk"}, inplace=True)

# %%
df.rename(columns={"UYRUK_ULKE_KOD": "uyruk ülke kodu"}, inplace=True)

# %%
df.rename(columns={"KULLANIM_CEP": "cep telefonu kullanımı"}, inplace=True)

# %%
df.rename(columns={"CEP_SAHIP": "cep telefonuna sahip"}, inplace=True)

# %%
df.rename(columns={"SON_KULLANIM_INTERNET": "en son internet ne zaman kullanıldı"}, inplace=True)

# %%
df.rename(columns={"KULLANIM_SIKLIK_INTERNET": "internet kullanım sıklığı"}, inplace=True)

# %%
df.rename(columns={"FERT_INT_MASAUSTU": "masaüstü kullanımı"}, inplace=True)

# %%
df.rename(columns={"FERT_INT_DIZUSTU": "dizüstü kullanımı"}, inplace=True)

# %%
df.rename(columns={"FERT_INT_TABLET": "tablet kullanımı"}, inplace=True)

# %%
df.rename(columns={"FERT_INT_TEL_CEP": "cep telefonu kullanımı"}, inplace=True)

# %%
df.rename(columns={"FERT_INT_DGR_CIHAZ": "diğer cihaz kullanımı"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_EPOSTA": "eposta kullanımı"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_TELEFON": "internet araması"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_SOSYAL_GRKATILIM": "sosyal medya kullanımı"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_MESAJ": "sosyal medyada mesajlaşma"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_ONLINE_HABER": "online haber okuma"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_SAGLIK_BILGI_ARM": "sağlık bilgisi arama"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_SAGLIK_BILGI_ARM_F": "fiziksel sağlık bilgisi arama"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_SAGLIK_BILGI_ARM_R": "ruhsal sağlık bilgisi arama"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_MALHIZ_BILGI": "ürün hizmet arama"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_MALHIZ_BILGI_GVNLK": "ürün güvenliği hakkında arama"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_WEBSITE_PAYLASIM": "websitesinde içerik paylaşma"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_OYL_KTLM": "internetten oy katılım"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_ISARAMA": "internetten iş arama"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_MALHIZMET_SATIS": ""}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_BANKA_ISLEM": "internetten satış"}, inplace=True)

# %%
df.rename(columns={"YAPAYZEKA_KULLAN": "yapay zeka kullanımı"}, inplace=True)

# %%
df.rename(columns={"YAPAYZEKA_AMAC_OZEL": "yapay zeka özel amaç kullanımı"}, inplace=True)

# %%
df.rename(columns={"YAPAYZEKA_AMAC_IS": "yapay zeka iş için kullanımı"}, inplace=True)

# %%
df.rename(columns={"YAPAYZEKA_AMAC_EGT_FRML": "yapay zeka eğitim için kullanımı"}, inplace=True)

# %%
df.rename(columns={"YAPAYZEKA_KULLANMAMA_NEDEN": "yapay zeka kullanmama nedeni"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_EGT_KURS": "online kurs"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_EGT_OGRN_MTRYL": "online eğitim materyal"}, inplace=True)

# %%
df.rename(columns={"INT_FAAL_EGT_WEB": "online eğitim iletişim"}, inplace=True)

# %%
df.rename(columns={"KULLAN_WHATSAPP": "whatsapp kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_INSTAGRAM": "instagram kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_YOUTUBE": "youtube kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_FACEBOOK": "facebook kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_TWITTER": "twitter kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_TELEGRAM": "telegram kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_TIKTOK": "tiktok kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_SNAPCHAT": "snapchat kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_BIP": "bip kullanımı"}, inplace=True)

# %%
df.rename(columns={"KULLAN_DIGER": "diğer mobil uygulama kullanımları"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_KSL_BILGI_ERISME": "edevlet resmi işlem"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_KAMU_BILGI_ERISME": "edevlet kamu bilgi"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_BILGI_EDINME": "edevlet hakkında bilgi"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_HICBIRI": "edevlette hiçbir sey yapmadı"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_FORM_INDIRME": "edevlet form işlemleri"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_RANDEVU_REZRVSYN": "edevletten randevu alma"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_HESAP_BLG_ALMA": "edevletten bilgi alma"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_KSL_VERGI_ONAY": "edevlet vergi işlem"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_TALEP_BELGE_SRTFKA": "edevlet belge talep"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_TALEP_YARDIM_HAK": "edevlet yardım talep"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_TALEP_DIGER": "edevlet diğer talepler"}, inplace=True)

# %%
df.rename(columns={"EDEVLET_TALEP_HIC_IHTIYACYOK": "edevletten talepe ihtiyaç yok"}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
df.rename(columns={"": ""}, inplace=True)

# %%
cols = list(df.columns)
len(cols), cols[69:100], cols[69:100]
# Out:
# (157,
#  ['edevletten talepe ihtiyaç yok',
#   'EDEVLET_TALEP_HIC_EKSKBILG',
#   'EDEVLET_TALEP_HIC_GUVENSIZ',
#   'EDEVLET_TALEP_HIC_EKIMLIKYOK',
#   'EDEVLET_TALEP_HIC_BASKASI',
#   'EDEVLET_TALEP_HIC_DIGER',
#   'EDEVLET_SORUN_ZOR',
#   'EDEVLET_SORUN_TEKNIK',
#   'EDEVLET_SORUN_E_IMZA_KIMLIK',
#   'EDEVLET_SORUN_ODEME',
#   'EDEVLET_SORUN_MOBIL_ERISIM',
#   'EDEVLET_SORUN_DIGER',
#   'EDEVLET_SORUN_HIC',
#   'EKIMLIK_ERSM_OZEL_AMAC',
#   'EKIMLIK_KAMU_HZMT',
#   'EKIMLIK_OZEL_HZMT',
#   'EKIMLIK_KLLNMM_SBP_HBR_DGL',
#   'EKIMLIK_KLLNMM_SBP_YOK',
#   'EKIMLIK_KLLNMM_SBP_GRKMD',
#   'EKIMLIK_KLLNMM_SBP_GVNSZ',
#   'EKIMLIK_KLLNMM_SBP_TKNK_SRN',
#   'EKIMLIK_KLLNMM_SBP_AKL_TLF_TBL',
#   'EKIMLIK_KLLNMM_SBP_DGR',
#   'SON_KULLANIM_ETICARET',
#   'ETICARET_FIZIKSEL',
#   'WEBSTE_INT_MOBL_ABONE',
#   'WEBSTE_ELK_SU_ABONE',
#   'WEBSTE_UYGL_ULASIM',
#   'WEBSTE_UYGL_RZV_KONAKLAMA',
#   'WEBSTE_BILET',
#   'WEBSTE_KITAP_E_SESLI'],
#  ['edevletten talepe ihtiyaç yok',
#   'EDEVLET_TALEP_HIC_EKSKBILG',
#   'EDEVLET_TALEP_HIC_GUVENSIZ',
#   'EDEVLET_TALEP_HIC_EKIMLIKYOK',
#   'EDEVLET_TALEP_HIC_BASKASI',
#   'EDEVLET_TALEP_HIC_DIGER',
#   'EDEVLET_SORUN_ZOR',
#   'EDEVLET_SORUN_TEKNIK',
#   'EDEVLET_SORUN_E_IMZA_KIMLIK',
#   'EDEVLET_SORUN_ODEME',
#   'EDEVLET_SORUN_MOBIL_ERISIM',
#   'EDEVLET_SORUN_DIGER',
#   'EDEVLET_SORUN_HIC',
#   'EKIMLIK_ERSM_OZEL_AMAC',
#   'EKIMLIK_KAMU_HZMT',
#   'EKIMLIK_OZEL_HZMT',
#   'EKIMLIK_KLLNMM_SBP_HBR_DGL',
#   'EKIMLIK_KLLNMM_SBP_YOK',
#   'EKIMLIK_KLLNMM_SBP_GRKMD',
#   'EKIMLIK_KLLNMM_SBP_GVNSZ',
#   'EKIMLIK_KLLNMM_SBP_TKNK_SRN',
#   'EKIMLIK_KLLNMM_SBP_AKL_TLF_TBL',
#   'EKIMLIK_KLLNMM_SBP_DGR',
#   'SON_KULLANIM_ETICARET',
#   'ETICARET_FIZIKSEL',
#   'WEBSTE_INT_MOBL_ABONE',
#   'WEBSTE_ELK_SU_ABONE',
#   'WEBSTE_UYGL_ULASIM',
#   'WEBSTE_UYGL_RZV_KONAKLAMA',
#   'WEBSTE_BILET',
#   'WEBSTE_KITAP_E_SESLI'])

# %%
df.head()
# Out:
#    bülten no  referans yıl  fert no  cinsiyet  yaş  yakınlık durumu  eğitim  \
