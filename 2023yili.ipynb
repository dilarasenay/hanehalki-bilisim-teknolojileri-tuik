# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\HBTKA_FERT_2023.csv" , sep=";")

df.head()
# Out:
# C:\Users\dilara\AppData\Local\Temp\ipykernel_33616\988822844.py:3: DtypeWarning: Columns (0: DOGUM_YER_ULKE_KOD, 1: UYRUK_ULKE_KOD) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\HBTKA_FERT_2023.csv" , sep=";")
#    REFERANS_YIL  BULTEN_NO  FERTNO  CEVAPLILIK_DURUM_FERT  CINSIYET  YAS  \
# 0          2023      10011       2                      1         1   45
# 1          2023      10012       1                      1         2   25
# 2          2023      10013       1                      1         1   58
# 3          2023      10014       2                      1         1   25
# 4          2023      10014       3                      1         2   40
#
#    OKUL_BITEN  OKUMA_YAZMA  CALISMA_DURUM  CALISMAMA_NEDEN  ...  \
# 0           3          NaN              1              NaN  ...
# 1         512          NaN              1              NaN  ...
# ...

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 19337     13
# 14763      8
# 19586      8
# 22495      8
# 10766      7
#           ..
# 236410     1
# 23657      1
# 23683      1
# 23693      1
# 23698      1
# Name: count, Length: 11289, dtype: int64
