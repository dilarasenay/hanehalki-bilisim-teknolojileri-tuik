# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\fert_2016.csv" , sep=";")

df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  FERTNO  CEVAPLILIK_DURUM_FERT  CEVAPSIZ_FERT  YAS  \
# 0          2016      10011       1                    1.0            NaN   50
# 1          2016      10011       2                    1.0            NaN   49
# 2          2016      10011       3                    2.0            1.0   21
# 3          2016      10011       4                    NaN            NaN   15
# 4          2016      10012       1                    1.0            NaN   43
#
#    CINSIYET  OKUMA_YAZMA  OKUL_BITEN  CALISMA_DURUM  ...  \
# 0         1          1.0         3.0            1.0  ...
# 1         2          1.0         3.0            3.0  ...
# 2         1          1.0         NaN            NaN  ...
# 3         1          1.0         NaN            NaN  ...
# 4         2          1.0         1.0            3.0  ...
#
#    INT_KBILGI_KORU_SINIR_SOSYAL  INT_KBILGI_KORU_IZINVRMEME  \
# 0                           2.0                         2.0
# ...

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 21221     20
# 19325     18
# 21193     18
# 23511     18
# 18785     17
#           ..
# 232410     1
# 233110     1
# 233210     1
# 234410     1
# 235310     1
# Name: count, Length: 11874, dtype: int64
