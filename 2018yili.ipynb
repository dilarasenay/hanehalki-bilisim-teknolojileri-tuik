# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\fert_2018.csv",
    sep=";",
    low_memory=False
)

df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  FERTNO  CEVAPLILIK_DURUM_FERT  YAS  CINSIYET  \
# 0          2018      11058       1                      1   19         1
# 1          2018      11058       4                      1   16         1
# 2          2018      11325       2                      1   34         1
# 3          2018      11863       4                      1   22         1
# 4          2018      12096       1                      1   27         1
#
#    OKUMA_YAZMA  OKUL_BITEN  CALISMA_DURUM  CALISMA_SAHIP_IS  ...  \
# 0            1           4              3               2.0  ...
# 1            1           3              3               2.0  ...
# 2            1           2              1               NaN  ...
# 3            1          51              1               NaN  ...
# 4            1           4              1               NaN  ...
#
#    ISYERI_BT_YENI_OGRN_ZRN  ISYERI_BT_YETERLILIK  EVDEN_CALISMA  \
# 0                      NaN                   NaN            NaN
# 1                      NaN                   NaN            NaN
# 2                      NaN                   NaN            NaN
# 3                      2.0                   1.0           90.0
# 4                      NaN                   NaN            NaN
#
#    EVDEN_CALISMA_ISICIN_INT_KUL  EYETENEK_UCRTSZ_ONLINE_KSL_CAL  \
# 0                           NaN                             2.0
# 1                           NaN                             2.0
# 2                           NaN                             2.0
# 3                           NaN                             2.0
# 4                           NaN                             2.0
#
#    EYETENEK_UCRT_EGTPRG_KENDI  EYETENEK_KAMU_UCRTSZ_KURS_KTLM  \
# 0                         2.0                             2.0
# 1                         2.0                             2.0
# 2                         2.0                             2.0
# 3                         2.0                             2.0
# 4                         2.0                             2.0
#
#    EYETENEK_UCRT_EGTPRG_ISYERI  EYETENEK_IS_EGTM_KTLM       FAKTOR
# 0                          2.0                    2.0  3852,219301
# 1                          2.0                    2.0  3852,219301
# 2                          2.0                    2.0  1749,850517
# 3                          2.0                    2.0  2848,618139
# 4                          2.0                    2.0  1775,022946
#
# [5 rows x 108 columns]

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 11645     9
# 20176     9
# 20235     9
# 24873     9
# 25713     9
#          ..
# 25674     1
# 25681     1
# 25685     1
# 257110    1
# 25717     1
# Name: count, Length: 12822, dtype: int64

# %%
df["REFERANS_YIL"].value_counts()
# Out:
# REFERANS_YIL
# 2018    28888
# Name: count, dtype: int64

# %%
df.rename(columns={"REFERANS_YIL": "referans yıl"}, inplace=True)

# %%
df.rename(columns={"BULTEN_NO": "bülten no"}, inplace=True)

# %%
df.rename(columns={"FERTNO": "fert no"}, inplace=True)

# %%
df.head()
# Out:
#    referans yıl  bülten no  fert no  CEVAPLILIK_DURUM_FERT  YAS  CINSIYET  \
# 0          2018      11058        1                      1   19         1
# 1          2018      11058        4                      1   16         1
# 2          2018      11325        2                      1   34         1
# 3          2018      11863        4                      1   22         1
# 4          2018      12096        1                      1   27         1
#
#    OKUMA_YAZMA  OKUL_BITEN  CALISMA_DURUM  CALISMA_SAHIP_IS  ...  \
# 0            1           4              3               2.0  ...
# 1            1           3              3               2.0  ...
# 2            1           2              1               NaN  ...
# 3            1          51              1               NaN  ...
# 4            1           4              1               NaN  ...
#
#    ISYERI_BT_YENI_OGRN_ZRN  ISYERI_BT_YETERLILIK  EVDEN_CALISMA  \
# 0                      NaN                   NaN            NaN
# 1                      NaN                   NaN            NaN
# 2                      NaN                   NaN            NaN
# 3                      2.0                   1.0           90.0
# 4                      NaN                   NaN            NaN
#
#    EVDEN_CALISMA_ISICIN_INT_KUL  EYETENEK_UCRTSZ_ONLINE_KSL_CAL  \
# 0                           NaN                             2.0
# 1                           NaN                             2.0
# 2                           NaN                             2.0
# 3                           NaN                             2.0
# 4                           NaN                             2.0
#
#    EYETENEK_UCRT_EGTPRG_KENDI  EYETENEK_KAMU_UCRTSZ_KURS_KTLM  \
# 0                         2.0                             2.0
# 1                         2.0                             2.0
# 2                         2.0                             2.0
# 3                         2.0                             2.0
# 4                         2.0                             2.0
#
#    EYETENEK_UCRT_EGTPRG_ISYERI  EYETENEK_IS_EGTM_KTLM       FAKTOR
# 0                          2.0                    2.0  3852,219301
# 1                          2.0                    2.0  3852,219301
# 2                          2.0                    2.0  1749,850517
# 3                          2.0                    2.0  2848,618139
# 4                          2.0                    2.0  1775,022946
#
# [5 rows x 108 columns]
