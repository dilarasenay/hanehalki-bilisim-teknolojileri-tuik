# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\hane_2015.csv",sep=";" )
df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  BT_BILGISAYAR_MASAUSTU  BT_BILGISAYAR_TASINABILIR  \
# 0          2015      10011                     2.0                        1.0
# 1          2015      10012                     2.0                        1.0
# 2          2015      10013                     2.0                        1.0
# 3          2015      10014                     2.0                        1.0
# 4          2015      10015                     2.0                        1.0
#
#    BT_TELEFON_CEP  BT_OYUNKONSOL  BT_TELEFON_SABIT  BT_FOTOGRAF_KAMERA  \
# 0             1.0            2.0               2.0                 2.0
# 1             1.0            2.0               1.0                 1.0
# 2             1.0            2.0               1.0                 1.0
# 3             1.0            2.0               2.0                 1.0
# 4             1.0            1.0               1.0                 1.0
#
# ...
