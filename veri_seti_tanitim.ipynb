# %% [markdown]
# # Veri Seti Değişken Açıklamaları
# ---
#
# ## 1. Hane Bilgileri
#
# ### REFERANS_YIL
# Anketin uygulandığı yılı göstermektedir.
#
# ### BULTEN_NO
# Rastgele üretilmiş hane ve fert soru formuna ilişkin anahtar değişkendir.
#
# ### BT_BILG_MASAUSTU
# Hanede masaüstü bilgisayar bulunma durumunu göstermektedir.
#
# ### BT_BILG_DIZUSTU
# Hanede dizüstü bilgisayar (laptop, notebook vb.) bulunma durumunu göstermektedir.
#
# ### BT_TABLET
# Hanede tablet bilgisayar bulunma durumunu göstermektedir.
#
# ### HANE_INTERNET_ERISIM_DURUMU
# Hanenin evden internete erişim durumunu göstermektedir.
#
# ### hane_aylik_gelir_grp_5
# Hanenin aylık net gelirinin 5’li gelir grubu içerisindeki konumunu göstermektedir.
#
# ### HHB
# Hanede yaşayan kişi sayısını ifade etmektedir.
#
# ### IBBS_1
# İstatistiki Bölge Birimleri Sınıflaması (Düzey 1) bilgisini göstermektedir.
#
# ### MAH_DEG_L1
# Yerleşim türünü (kır, orta yoğun kent, yoğun kent) göstermektedir.
#
# ### HANE_FAKTOR
# Hane ağırlık katsayısını ifade etmektedir.
#
# ---
#
# ## 2. Fert Bilgileri
#
# ### GORUSME_YONTEM_FERT
# Fert ile yapılan görüşme yöntemini göstermektedir.
#
# ### FERTNO
# Ferdin hane içerisindeki sıra numarasıdır.
#
# ### CINSIYET
# Ferdin cinsiyetini göstermektedir.
#
# ### YAS
# Ferdin tamamlanmış yaşını göstermektedir.
#
# ### HHSORUMLU_YAKINLIK
# Ferdin hane sorumlusuna olan yakınlık derecesini göstermektedir.
#
# ### OKUL_BITEN
# Ferdin tamamladığı eğitim düzeyini göstermektedir.
#
# ### OKUMA_YAZMA
# Ferdin okuryazarlık durumunu göstermektedir.
#
# ### CALISMA_DURUM
# Ferdin son bir hafta içindeki çalışma durumunu göstermektedir.
#
# ### CALISMAMA_NEDEN
# Ferdin çalışmama veya iş aramama nedenini göstermektedir.
#
# ### ISTEKI_DURUM
# Ferdin işteki durumunu göstermektedir.
#
# ### ISCO08
# Ferdin meslek sınıflamasını göstermektedir.
#
# ### DOGUM_YER
# Ferdin doğduğu ülkeyi göstermektedir.
#
# ### DOGUM_YER_ULKE_KOD
# Doğduğu ülkenin kodunu göstermektedir.
#
# ### UYRUK
# Ferdin vatandaşlık durumunu göstermektedir.
#
# ### UYRUK_ULKE_KOD
# Vatandaşlık ülkesinin kodunu göstermektedir.
#
# ---
#
# ## 3. Cep Telefonu Kullanımı
#
# ### KULLANIM_CEP
# Ferdin cep telefonu kullanıp kullanmadığını göstermektedir.
#
# ### CEP_SAHIP
# Ferdin cep telefonuna sahip olup olmadığını göstermektedir.
#
# ---
#
# ## 4. İnternet Kullanımı
#
# ### SON_KULLANIM_INTERNET
# Ferdin son internet kullanım zamanını göstermektedir.
#
# ### KULLANIM_SIKLIK_INTERNET
# İnternet kullanım sıklığını göstermektedir.
#
# ### FERT_INT_MASAUSTU
# Masaüstü bilgisayar ile internet kullanımı.
#
# ### FERT_INT_DIZUSTU
# Dizüstü bilgisayar ile internet kullanımı.
#
# ### FERT_INT_TABLET
# Tablet ile internet kullanımı.
#
# ### FERT_INT_TEL_CEP
# Cep telefonu ile internet kullanımı.
#
# ### FERT_INT_DIGER_CIHAZ
# Diğer cihazlar ile internet kullanımı.
#
# ---
#
# ## 5. İnternet Faaliyetleri
#
# ### INT_FAAL_EPOSTA
# E-posta gönderme veya alma.
#
# ### INT_FAAL_TELEFON
# İnternet üzerinden sesli/görüntülü görüşme.
#
# ### INT_FAAL_SOSYAL_GRKATILIM
# Sosyal ağlara katılım ve içerik paylaşımı.
#
# ### INT_FAAL_MESAJ
# Mesajlaşma uygulamalarını kullanma.
#
# ### INT_FAAL_ONLINE_HABER
# Online haber okuma.
#
# ### INT_FAAL_SAGLIK_BILGI_ARM
# Sağlıkla ilgili bilgi arama.
#
# ### INT_FAAL_SAGLIK_BILGI_ARM_F
# Fiziksel sağlıkla ilgili bilgi arama.
#
# ### INT_FAAL_SAGLIK_BILGI_ARM_R
# Ruhsal sağlıkla ilgili bilgi arama.
#
# ### INT_FAAL_MALHIZ_BILGI
# Mal ve hizmetler hakkında bilgi arama.
#
# ### INT_FAAL_MALHIZ_BILGI_GVNLK
# Güvenlik hakkında bilgi arama.
#
# ### INT_FAAL_WEBSITE_PAYLASIM
# Web sitesi veya blog paylaşımı.
#
# ### INT_FAAL_OYL_KATILIM
# Online oylamalara katılım.
#
# ### INT_FAAL_ISARAMA
# İş arama veya başvuru yapma.
#
# ### INT_FAAL_MALHIZMET_SATIS
# Online satış yapma.
#
# ### INT_FAAL_BANKA_ISLEM
# İnternet bankacılığı kullanımı.
#
# ---
#
# ## 6. Yapay Zeka Kullanımı
#
# ### YAPAYZEKA_KULLAN
# Yapay zeka araçlarını kullanma durumu.
#
# ### YAPAYZEKA_AMAC_OZEL
# Kişisel amaçlı kullanım.
#
# ### YAPAYZEKA_AMAC_IS
# İş amaçlı kullanım.
#
# ### YAPAYZEKA_AMAC_EGT
# Eğitim amaçlı kullanım.
#
# ### YAPAYZEKA_KULLANMAMA_NEDEN
# Yapay zekayı kullanmama nedenleri.
#
# ---
#
# ## 7. Eğitim Amaçlı İnternet Kullanımı
#
# ### INT_FAAL_EGT_KURS
# Online kurslara katılım.
#
# ### INT_FAAL_EGT_OGRN_MTRYL
# Online eğitim materyali kullanımı.
#
# ### INT_FAAL_EGT_WEB
# Online eğitim platformları kullanımı.
#
# ---
#
# ## 8. Sosyal Medya Kullanımı
#
# ### KULLAN_WHATSAPP
# ### KULLAN_INSTAGRAM
# ### KULLAN_YOUTUBE
# ### KULLAN_FACEBOOK
# ### KULLAN_TWITTER
# ### KULLAN_TELEGRAM
# ### KULLAN_TIKTOK
# ### KULLAN_SNAPCHAT
# ### KULLAN_BIP
# ### KULLAN_DIGER
#
# Bireyin ilgili platformları kullanma durumunu göstermektedir.
#
# ---
#
# ## 9. E-Devlet Kullanımı
#
# ### EDEVLET_KSL_BILGI_ERISME
# ### EDEVLET_KAMU_BILGI_ERISME
# ### EDEVLET_BILGI_EDINME
# ### EDEVLET_HICBIRI
#
# Kamu hizmetlerine erişim türlerini göstermektedir.
#
# ### EDEVLET_FORM_INDIRME
# Resmi form indirme/gönderme.
#
# ### EDEVLET_RANDEVU_REZERVASYON
# Randevu alma.
#
# ### EDEVLET_HESAP_BILGI_ALMA
# Resmi hesap bilgilerine erişim.
#
# ### EDEVLET_KSL_VERGI_ONAY
# Vergi işlemleri.
#
# ### EDEVLET_TALEP_BELGE
# Belge talebi.
#
# ### EDEVLET_TALEP_YARDIM
# Yardım başvurusu.
#
# ### EDEVLET_TALEP_DIGER
# Diğer başvurular.
#
# ---
#
# ## 10. E-Ticaret
#
# ### SON_KULLANIM_ETICARET
# E-ticaret kullanım zamanı.
#
# ### ETICARET_FIZIKSEL
# Fiziksel ürün satın alma.
#
# ### WEBSITE_* değişkenleri
# Online satın alınan ürün/hizmet türleri (ulaşım, konaklama, medya, yazılım vb.).
#
# ### ETICARET_SORUN_* değişkenleri
# Online alışverişte karşılaşılan problemler.
#
# ---
#
# ## 11. Dijital Beceriler
#
# ### EYETENEK_BLG_MOBIL_DOSYA
# Dosya yönetimi.
#
# ### EYETENEK_YAZILIM_KULLANIM
# Yazılım kullanımı.
#
# ### EYETENEK_KOD_YAZMA
# Kod yazma.
#
# ### EYETENEK_VERI_ANALIZ
# Veri analizi becerisi.
#
# ---
#
# ## 12. Bilgi Doğrulama
#
# ### EBECERI_ICERIK_SUPHE
# Şüpheli içerikle karşılaşma.
#
# ### EBECERI_ICERIK_KONTROL
# Bilgi doğrulama davranışı.
#
# ---
#
# ## 13. Güvenlik ve Gizlilik
#
# ### INT_KBILGI_KORU_*
# Kişisel veri koruma davranışları.
#
# ### INT_KBILGI_CEREZ
# Çerez yönetimi.
#
# ### INT_KBILGI_ETKINLIK_SINIR
# Reklam ve izleme sınırlama.
#
# ### INT_HESAP_AC
# Online hesap oluşturma.
#
# ### INT_HESAP_SIL
# Hesap silme.
#
# ---
#
# ## 14. Elektronik Kimlik
#
# ### EKIMLIK_*
# Elektronik kimlik kullanım durumları.
#
# ---
#
# ## 15. Ağırlık Değişkenleri
#
# ### FERT_FAKTOR
# Fert ağırlık katsayısı.
#
# ### HANE_FAKTOR
# Hane ağırlık katsayısı.
