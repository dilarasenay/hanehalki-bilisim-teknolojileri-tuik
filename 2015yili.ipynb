# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\dilara\Desktop\Hane halkı bilişim tüik\fert_2015.csv", sep=";",
    encoding="latin-1" )

df.head()
# Out:
#    REFERANS_YIL  BULTEN_NO  FERTNO  CEVAPLILIK_DURUM_FERT    FERT_DURUM  \
# 0          2015      10011       1                    1.0  CEVAPLI FERT
# 1          2015      10012       3                    1.0  CEVAPLI FERT
# 2          2015      10012       2                    1.0  CEVAPLI FERT
# 3          2015      10012       1                    1.0  CEVAPLI FERT
# 4          2015      10013       3                    1.0  CEVAPLI FERT
#
#    CEVAPSIZ_FERT  CEVAP_FERT  CEVAP_FERTNO  YAS  CINSIYET  ...  \
# 0            NaN         1.0           NaN   58         1  ...
# 1            NaN         1.0           NaN   20         1  ...
# 2            NaN         1.0           NaN   48         2  ...
# 3            NaN         1.0           NaN   54         1  ...
# 4            NaN         1.0           NaN   39         2  ...
#
#    INT_GUVENLIK_VZGCM_BANKISLM  INT_GUVENLIK_VZGCM_SOSYALAG  \
# 0                          2.0                          2.0
# ...

# %%
df["BULTEN_NO"].value_counts()
# Out:
# BULTEN_NO
# 20181     24
# 22067     20
# 20246     19
# 20241     17
# 20245     17
#           ..
# 22101      1
# 22136      1
# 221310     1
# 22171      1
# 22219      1
# Name: count, Length: 10326, dtype: int64
